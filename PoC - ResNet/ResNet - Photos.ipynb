# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8676721314572919166
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5415755066696400485
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla ResNetu

IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0  ../data/Photos/photoshops/co20t8o_0.png         0
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg         0
# 2  ../data/Photos/photoshops/d23zitu_0.png         0
# 3  ../data/Photos/photoshops/cxevpq7_0.png         0
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg         0

# %%
df.shape
# Out:
# (21896, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0  ../data/Photos/photoshops/co20t8o_0.png         0
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg         0
# 2  ../data/Photos/photoshops/d23zitu_0.png         0
# 3  ../data/Photos/photoshops/cxevpq7_0.png         0
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg         0

# %%
X.head()
# Out:
#                                   filename
# 0  ../data/Photos/photoshops/co20t8o_0.png
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg
# 2  ../data/Photos/photoshops/d23zitu_0.png
# 3  ../data/Photos/photoshops/cxevpq7_0.png
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21896, 2)
# 	 train: (17516, 2)
# 	 test: (4380, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21896, 2)
# 	 train: (17516, 2)
# 	 test: (4380, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
# To Do

batch_size = 10
activation = 'relu'
loss_type = 'categorical_crossentropy'
optimizer = 'Adam'
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
 * losowa rotacja o 15 stopni
 * reskalowanie
 * przybliżenie
 * obrót horyzontalny
 * zakresy dla przesunieć wertykalnych i horyzontalnych
'''

from keras.applications.resnet import preprocess_input

data_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17516 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4380 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50

pre_trained_model_fn = ResNet50(include_top = False, pooling = 'avg', weights = 'imagenet')

for layer in pre_trained_model_fn.layers[:15]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[15:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dropout(dropout))
model_fn.add(BatchNormalization())
model_fn.add(Dense(2, activation='softmax'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 24,113,794
# Trainable params: 23,975,938
# Non-trainable params: 137,856
# _________________________________________________________________

# %% [markdown]
# # ResNet bez żadnych wag wejściowych

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50

pre_trained_model_v = ResNet50(include_top = True, weights = None, classes=2)

model_v = Sequential()

model_v.add(pre_trained_model_v)

model_v.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2)                 23591810
# =================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P.h5')
# Out:
# Epoch 1/50
#  728/1751 [===========>..................] - ETA: 4:15 - loss: 0.7771 - accuracy: 0.5077 - get_f1: 0.5076
# d:\programs\python37\lib\site-packages\PIL\Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 1751/1751 [==============================] - 477s 272ms/step - loss: 0.7414 - accuracy: 0.5050 - get_f1: 0.5049 - val_loss: 0.6933 - val_accuracy: 0.5011 - val_get_f1: 0.5011
#
# Epoch 00001: val_loss improved from inf to 0.69326, saving model to best.h5
# Epoch 2/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.7033 - accuracy: 0.4991 - get_f1: 0.4991 - val_loss: 1.0775 - val_accuracy: 0.5164 - val_get_f1: 0.5164
#
# Epoch 00002: val_loss did not improve from 0.69326
# Epoch 3/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6954 - accuracy: 0.5411 - get_f1: 0.5411 - val_loss: 3.6425 - val_accuracy: 0.5685 - val_get_f1: 0.5685
#
# Epoch 00003: val_loss did not improve from 0.69326
# Epoch 4/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6886 - accuracy: 0.5604 - get_f1: 0.5604 - val_loss: 0.6397 - val_accuracy: 0.5498 - val_get_f1: 0.5498
#
# Epoch 00004: val_loss improved from 0.69326 to 0.63973, saving model to best.h5
# Epoch 5/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6843 - accuracy: 0.5609 - get_f1: 0.5608 - val_loss: 36.2862 - val_accuracy: 0.4763 - val_get_f1: 0.4763
#
# Epoch 00005: val_loss did not improve from 0.63973
# Epoch 6/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6805 - accuracy: 0.5719 - get_f1: 0.5718 - val_loss: 0.4920 - val_accuracy: 0.5731 - val_get_f1: 0.5731
#
# Epoch 00006: val_loss improved from 0.63973 to 0.49200, saving model to best.h5
# Epoch 7/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6762 - accuracy: 0.5810 - get_f1: 0.5810 - val_loss: 0.6903 - val_accuracy: 0.5744 - val_get_f1: 0.5744
#
# Epoch 00007: val_loss did not improve from 0.49200
# Epoch 8/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6764 - accuracy: 0.5741 - get_f1: 0.5742 - val_loss: 0.6550 - val_accuracy: 0.5406 - val_get_f1: 0.5406
#
# Epoch 00008: val_loss did not improve from 0.49200
# Epoch 9/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6738 - accuracy: 0.5840 - get_f1: 0.5841 - val_loss: 0.5502 - val_accuracy: 0.5719 - val_get_f1: 0.5719
#
# Epoch 00009: val_loss did not improve from 0.49200
# Epoch 10/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6717 - accuracy: 0.5868 - get_f1: 0.5868 - val_loss: 0.8057 - val_accuracy: 0.5922 - val_get_f1: 0.5922
#
# Epoch 00010: val_loss did not improve from 0.49200
# Epoch 11/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6688 - accuracy: 0.5909 - get_f1: 0.5909 - val_loss: 0.5264 - val_accuracy: 0.5856 - val_get_f1: 0.5856
#
# Epoch 00011: val_loss did not improve from 0.49200
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6660 - accuracy: 0.5961 - get_f1: 0.5961 - val_loss: 4.0289 - val_accuracy: 0.5970 - val_get_f1: 0.5970
#
# Epoch 00012: val_loss did not improve from 0.49200
# Epoch 13/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6599 - accuracy: 0.6062 - get_f1: 0.6063 - val_loss: 0.5578 - val_accuracy: 0.5922 - val_get_f1: 0.5922
#
# Epoch 00013: val_loss did not improve from 0.49200
# Epoch 14/50
# 1751/1751 [==============================] - 465s 266ms/step - loss: 0.6605 - accuracy: 0.6040 - get_f1: 0.6040 - val_loss: 9.9727 - val_accuracy: 0.5991 - val_get_f1: 0.5991
#
# Epoch 00014: val_loss did not improve from 0.49200
# Epoch 15/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6539 - accuracy: 0.6157 - get_f1: 0.6156 - val_loss: 0.5129 - val_accuracy: 0.5979 - val_get_f1: 0.5979
#
# Epoch 00015: val_loss did not improve from 0.49200
# Epoch 16/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6525 - accuracy: 0.6193 - get_f1: 0.6193 - val_loss: 0.6412 - val_accuracy: 0.5943 - val_get_f1: 0.5943
#
# Epoch 00016: val_loss did not improve from 0.49200
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 17/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6514 - accuracy: 0.6229 - get_f1: 0.6228 - val_loss: 0.6698 - val_accuracy: 0.5966 - val_get_f1: 0.5966
#
# Epoch 00017: val_loss did not improve from 0.49200
# Epoch 18/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6512 - accuracy: 0.6229 - get_f1: 0.6229 - val_loss: 8.9622 - val_accuracy: 0.5938 - val_get_f1: 0.5938
#
# Epoch 00018: val_loss did not improve from 0.49200
# Epoch 19/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6522 - accuracy: 0.6207 - get_f1: 0.6207 - val_loss: 0.5480 - val_accuracy: 0.5934 - val_get_f1: 0.5934
#
# Epoch 00019: val_loss did not improve from 0.49200
# Epoch 20/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6523 - accuracy: 0.6211 - get_f1: 0.6211 - val_loss: 0.6073 - val_accuracy: 0.5991 - val_get_f1: 0.5991
#
# Epoch 00020: val_loss did not improve from 0.49200
# Epoch 21/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6521 - accuracy: 0.6215 - get_f1: 0.6215 - val_loss: 0.4738 - val_accuracy: 0.5957 - val_get_f1: 0.5957
#
# Epoch 00021: val_loss improved from 0.49200 to 0.47383, saving model to best.h5
# Epoch 22/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6495 - accuracy: 0.6260 - get_f1: 0.6259 - val_loss: 9.3605 - val_accuracy: 0.5970 - val_get_f1: 0.5970
#
# Epoch 00022: val_loss did not improve from 0.47383
# Epoch 23/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6517 - accuracy: 0.6214 - get_f1: 0.6214 - val_loss: 0.8980 - val_accuracy: 0.5966 - val_get_f1: 0.5966
#
# Epoch 00023: val_loss did not improve from 0.47383
# Epoch 24/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6516 - accuracy: 0.6205 - get_f1: 0.6205 - val_loss: 0.5785 - val_accuracy: 0.6011 - val_get_f1: 0.6011
#
# Epoch 00024: val_loss did not improve from 0.47383
# Epoch 25/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6498 - accuracy: 0.6216 - get_f1: 0.6215 - val_loss: 0.7907 - val_accuracy: 0.5973 - val_get_f1: 0.5973
#
# Epoch 00025: val_loss did not improve from 0.47383
# Epoch 26/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6491 - accuracy: 0.6209 - get_f1: 0.6209 - val_loss: 0.5099 - val_accuracy: 0.5979 - val_get_f1: 0.5979
#
# Epoch 00026: val_loss did not improve from 0.47383
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 27/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6515 - accuracy: 0.6206 - get_f1: 0.6205 - val_loss: 0.6000 - val_accuracy: 0.5963 - val_get_f1: 0.5963
#
# Epoch 00027: val_loss did not improve from 0.47383
# Epoch 28/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6509 - accuracy: 0.6204 - get_f1: 0.6204 - val_loss: 11.8381 - val_accuracy: 0.5991 - val_get_f1: 0.5991
#
# Epoch 00028: val_loss did not improve from 0.47383
# Epoch 29/50
# 1751/1751 [==============================] - 464s 265ms/step - loss: 0.6508 - accuracy: 0.6221 - get_f1: 0.6220 - val_loss: 0.8015 - val_accuracy: 0.5982 - val_get_f1: 0.5982
#
# Epoch 00029: val_loss did not improve from 0.47383
# Epoch 30/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6487 - accuracy: 0.6285 - get_f1: 0.6284 - val_loss: 0.6351 - val_accuracy: 0.5982 - val_get_f1: 0.5982
#
# Epoch 00030: val_loss did not improve from 0.47383
# Epoch 31/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6476 - accuracy: 0.6268 - get_f1: 0.6268 - val_loss: 4.8055 - val_accuracy: 0.5963 - val_get_f1: 0.5963
#
# Epoch 00031: val_loss did not improve from 0.47383
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 32/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6487 - accuracy: 0.6234 - get_f1: 0.6235 - val_loss: 0.7004 - val_accuracy: 0.5968 - val_get_f1: 0.5968
#
# Epoch 00032: val_loss did not improve from 0.47383
# Epoch 33/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6498 - accuracy: 0.6230 - get_f1: 0.6230 - val_loss: 21.4942 - val_accuracy: 0.5979 - val_get_f1: 0.5979
# Epoch 00033: val_loss did not improve from 0.47383
# Epoch 34/50
# 1751/1751 [==============================] - 462s 264ms/step - loss: 0.6513 - accuracy: 0.6199 - get_f1: 0.6199 - val_loss: 51.0477 - val_accuracy: 0.5989 - val_get_f1: 0.5989
#
# Epoch 00034: val_loss did not improve from 0.47383
# Epoch 35/50
# 1751/1751 [==============================] - 463s 265ms/step - loss: 0.6491 - accuracy: 0.6249 - get_f1: 0.6249 - val_loss: 0.5241 - val_accuracy: 0.5954 - val_get_f1: 0.5954
#
# Epoch 00035: val_loss did not improve from 0.47383
# Epoch 36/50
# 1751/1751 [==============================] - 463s 264ms/step - loss: 0.6477 - accuracy: 0.6285 - get_f1: 0.6285 - val_loss: 0.6597 - val_accuracy: 0.5986 - val_get_f1: 0.5986
#
# Epoch 00036: val_loss did not improve from 0.47383
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00036: early stopping

# %%
'''
odświeżenie callbacków
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %%
model_v.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_v = model_v.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_v.load_weights('best.h5')

# Zapis
model_v.save('the_best_v_P.h5')
# Out:
# Epoch 1/50
#   49/1751 [..............................] - ETA: 13:34 - loss: 1.4128 - accuracy: 0.5449 - get_f1: 0.5449
# d:\programs\python37\lib\site-packages\PIL\Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 1751/1751 [==============================] - 539s 308ms/step - loss: 0.7659 - accuracy: 0.5160 - get_f1: 0.5160 - val_loss: 0.7238 - val_accuracy: 0.4954 - val_get_f1: 0.4954
#
# Epoch 00001: val_loss improved from inf to 0.72382, saving model to best.h5
# Epoch 2/50
# 1751/1751 [==============================] - 521s 298ms/step - loss: 0.7189 - accuracy: 0.5158 - get_f1: 0.5157 - val_loss: 0.6432 - val_accuracy: 0.5306 - val_get_f1: 0.5306
#
# Epoch 00002: val_loss improved from 0.72382 to 0.64315, saving model to best.h5
# Epoch 3/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.7110 - accuracy: 0.5211 - get_f1: 0.5211 - val_loss: 0.8700 - val_accuracy: 0.5626 - val_get_f1: 0.5626
#
# Epoch 00003: val_loss did not improve from 0.64315
# Epoch 4/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.7020 - accuracy: 0.5162 - get_f1: 0.5162 - val_loss: 0.7227 - val_accuracy: 0.5276 - val_get_f1: 0.5276
#
# Epoch 00004: val_loss did not improve from 0.64315
# Epoch 5/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.7038 - accuracy: 0.5266 - get_f1: 0.5266 - val_loss: 0.6576 - val_accuracy: 0.5135 - val_get_f1: 0.5135
#
# Epoch 00005: val_loss did not improve from 0.64315
# Epoch 6/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6945 - accuracy: 0.5286 - get_f1: 0.5286 - val_loss: 0.6789 - val_accuracy: 0.5548 - val_get_f1: 0.5548
#
# Epoch 00006: val_loss did not improve from 0.64315
# Epoch 7/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6890 - accuracy: 0.5428 - get_f1: 0.5429 - val_loss: 0.7068 - val_accuracy: 0.5491 - val_get_f1: 0.5491
#
# Epoch 00007: val_loss did not improve from 0.64315
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 8/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6843 - accuracy: 0.5535 - get_f1: 0.5534 - val_loss: 0.6361 - val_accuracy: 0.5623 - val_get_f1: 0.5623
#
# Epoch 00008: val_loss improved from 0.64315 to 0.63615, saving model to best.h5
# Epoch 9/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6823 - accuracy: 0.5594 - get_f1: 0.5594 - val_loss: 0.7069 - val_accuracy: 0.5767 - val_get_f1: 0.5767
#
# Epoch 00009: val_loss did not improve from 0.63615
# Epoch 10/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6805 - accuracy: 0.5656 - get_f1: 0.5656 - val_loss: 0.6853 - val_accuracy: 0.5742 - val_get_f1: 0.5742
#
# Epoch 00010: val_loss did not improve from 0.63615
# Epoch 11/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6791 - accuracy: 0.5667 - get_f1: 0.5667 - val_loss: 0.7296 - val_accuracy: 0.5797 - val_get_f1: 0.5797
#
# Epoch 00011: val_loss did not improve from 0.63615
# Epoch 12/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6769 - accuracy: 0.5720 - get_f1: 0.5720 - val_loss: 0.7138 - val_accuracy: 0.5813 - val_get_f1: 0.5813
#
# Epoch 00012: val_loss did not improve from 0.63615
# Epoch 13/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6740 - accuracy: 0.5784 - get_f1: 0.5784 - val_loss: 0.6914 - val_accuracy: 0.5893 - val_get_f1: 0.5893
#
# Epoch 00013: val_loss did not improve from 0.63615
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/50
# 1751/1751 [==============================] - 521s 297ms/step - loss: 0.6707 - accuracy: 0.5807 - get_f1: 0.5807 - val_loss: 0.6559 - val_accuracy: 0.5941 - val_get_f1: 0.5941
#
# Epoch 00014: val_loss did not improve from 0.63615
# Epoch 15/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6722 - accuracy: 0.5787 - get_f1: 0.5787 - val_loss: 0.6084 - val_accuracy: 0.5902 - val_get_f1: 0.5902
#
# Epoch 00015: val_loss improved from 0.63615 to 0.60836, saving model to best.h5
# Epoch 16/50
# 1751/1751 [==============================] - 520s 297ms/step - loss: 0.6705 - accuracy: 0.5799 - get_f1: 0.5800 - val_loss: 0.6900 - val_accuracy: 0.5881 - val_get_f1: 0.5881
#
# Epoch 00016: val_loss did not improve from 0.60836
# Epoch 17/50
# 1751/1751 [==============================] - 520s 297ms/step - loss: 0.6696 - accuracy: 0.5821 - get_f1: 0.5822 - val_loss: 0.7070 - val_accuracy: 0.5890 - val_get_f1: 0.5890
#
# Epoch 00017: val_loss did not improve from 0.60836
# Epoch 18/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6703 - accuracy: 0.5810 - get_f1: 0.5810 - val_loss: 0.6708 - val_accuracy: 0.5904 - val_get_f1: 0.5904
#
# Epoch 00018: val_loss did not improve from 0.60836
# Epoch 19/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6702 - accuracy: 0.5842 - get_f1: 0.5843 - val_loss: 0.7599 - val_accuracy: 0.5906 - val_get_f1: 0.5906
#
# Epoch 00019: val_loss did not improve from 0.60836
# Epoch 20/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6696 - accuracy: 0.5869 - get_f1: 0.5869 - val_loss: 0.7787 - val_accuracy: 0.5902 - val_get_f1: 0.5902
#
# Epoch 00020: val_loss did not improve from 0.60836
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 21/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6686 - accuracy: 0.5857 - get_f1: 0.5857 - val_loss: 0.5492 - val_accuracy: 0.5906 - val_get_f1: 0.5906
#
# Epoch 00021: val_loss improved from 0.60836 to 0.54925, saving model to best.h5
# Epoch 22/50
# 1751/1751 [==============================] - 519s 297ms/step - loss: 0.6690 - accuracy: 0.5852 - get_f1: 0.5851 - val_loss: 0.7296 - val_accuracy: 0.5886 - val_get_f1: 0.5886
#
# Epoch 00022: val_loss did not improve from 0.54925
# Epoch 23/50
# 1751/1751 [==============================] - 519s 297ms/step - loss: 0.6689 - accuracy: 0.5850 - get_f1: 0.5850 - val_loss: 0.5378 - val_accuracy: 0.5913 - val_get_f1: 0.5913
#
# Epoch 00023: val_loss improved from 0.54925 to 0.53778, saving model to best.h5
# Epoch 24/50
# 1751/1751 [==============================] - 520s 297ms/step - loss: 0.6692 - accuracy: 0.5837 - get_f1: 0.5837 - val_loss: 0.7489 - val_accuracy: 0.5916 - val_get_f1: 0.5916
#
# Epoch 00024: val_loss did not improve from 0.53778
# Epoch 25/50
# 1751/1751 [==============================] - 519s 297ms/step - loss: 0.6676 - accuracy: 0.5865 - get_f1: 0.5865 - val_loss: 0.7675 - val_accuracy: 0.5909 - val_get_f1: 0.5909
#
# Epoch 00025: val_loss did not improve from 0.53778
# Epoch 26/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6688 - accuracy: 0.5848 - get_f1: 0.5848 - val_loss: 0.8179 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00026: val_loss did not improve from 0.53778
# Epoch 27/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6687 - accuracy: 0.5845 - get_f1: 0.5845 - val_loss: 0.6630 - val_accuracy: 0.5893 - val_get_f1: 0.5893
#
# Epoch 00027: val_loss did not improve from 0.53778
# Epoch 28/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6683 - accuracy: 0.5868 - get_f1: 0.5868 - val_loss: 0.7937 - val_accuracy: 0.5922 - val_get_f1: 0.5922
#
# Epoch 00028: val_loss did not improve from 0.53778
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 29/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6680 - accuracy: 0.5892 - get_f1: 0.5892 - val_loss: 0.6210 - val_accuracy: 0.5904 - val_get_f1: 0.5904
#
# Epoch 00029: val_loss did not improve from 0.53778
# Epoch 30/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6681 - accuracy: 0.5852 - get_f1: 0.5852 - val_loss: 0.6456 - val_accuracy: 0.5895 - val_get_f1: 0.5895
#
# Epoch 00030: val_loss did not improve from 0.53778
# Epoch 31/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6689 - accuracy: 0.5857 - get_f1: 0.5857 - val_loss: 0.6425 - val_accuracy: 0.5902 - val_get_f1: 0.5902
#
# Epoch 00031: val_loss did not improve from 0.53778
# Epoch 32/50
# 1751/1751 [==============================] - 519s 296ms/step - loss: 0.6684 - accuracy: 0.5856 - get_f1: 0.5857 - val_loss: 0.6835 - val_accuracy: 0.5900 - val_get_f1: 0.5900
#
# Epoch 00032: val_loss did not improve from 0.53778
# Epoch 33/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6686 - accuracy: 0.5832 - get_f1: 0.5832 - val_loss: 0.7663 - val_accuracy: 0.5925 - val_get_f1: 0.5925
#
# Epoch 00033: val_loss did not improve from 0.53778
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 34/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6685 - accuracy: 0.5865 - get_f1: 0.5865 - val_loss: 0.7723 - val_accuracy: 0.5913 - val_get_f1: 0.5913
#
# Epoch 00034: val_loss did not improve from 0.53778
# Epoch 35/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6693 - accuracy: 0.5854 - get_f1: 0.5854 - val_loss: 0.9142 - val_accuracy: 0.5911 - val_get_f1: 0.5911
#
# Epoch 00035: val_loss did not improve from 0.53778
# Epoch 36/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6687 - accuracy: 0.5860 - get_f1: 0.5860 - val_loss: 0.6260 - val_accuracy: 0.5879 - val_get_f1: 0.5879
#
# Epoch 00036: val_loss did not improve from 0.53778
# Epoch 37/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6679 - accuracy: 0.5839 - get_f1: 0.5838 - val_loss: 0.7512 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00037: val_loss did not improve from 0.53778
# Epoch 38/50
# 1751/1751 [==============================] - 518s 296ms/step - loss: 0.6699 - accuracy: 0.5826 - get_f1: 0.5825 - val_loss: 0.7063 - val_accuracy: 0.5922 - val_get_f1: 0.5922
#
# Epoch 00038: val_loss did not improve from 0.53778
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00038: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_v.history['loss'], color='b', label="Training loss")
ax1.plot(history_v.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_v.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_v.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_v.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_v.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_v.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_v.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_v.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None,
    'predict_v': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn predict_v
# 0      ../data/Photos/originals/6588pa.jpg        1       None      None
# 1  ../data/Photos/photoshops/c8c91j4_0.jpg        0       None      None
# 2  ../data/Photos/photoshops/d4qa93b_0.jpg        0       None      None
# 3      ../data/Photos/originals/7b5cpd.jpg        1       None      None
# 4  ../data/Photos/photoshops/ckz1ae8_0.jpg        0       None      None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4380 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)

predict_v = model_v.predict_generator(validate_generator, verbose=True)
# Out:
# 438/438 [==============================] - 58s 132ms/step
# 438/438 [==============================] - 57s 129ms/step

# %%
# Zamiana z one hot encodera na jedno wyjście
stats_df['predict_fn'] = numpy.argmax(predict_fn, axis=-1)
stats_df['predict_v'] = numpy.argmax(predict_v, axis=-1)

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn  predict_v
# 0      ../data/Photos/originals/6588pa.jpg        1           1          1
# 1  ../data/Photos/photoshops/c8c91j4_0.jpg        0           1          1
# 2  ../data/Photos/photoshops/d4qa93b_0.jpg        0           1          1
# 3      ../data/Photos/originals/7b5cpd.jpg        1           1          0
# 4  ../data/Photos/photoshops/ckz1ae8_0.jpg        0           0          0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
stats_df['predict_v'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

y_true_v = stats_df['category'].to_numpy().astype(int)
y_pred_v = stats_df['predict_v'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)
cm_v = confusion_matrix(y_true_v, y_pred_v)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1182 1008]
#  [ 763 1427]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 438/438 [==============================] - 57s 131ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 3.54
# Test accuracy: 0.596
# Test F1: 0.596

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.595662100456621
# Precision: 0.5968745216239186
# Recall: 0.595662100456621
# F-score: 0.5943930193797183

# %%
plot_cm(cm_v, ['Originals', 'Photoshops'])

# %%
print(cm_v)
# Out:
# [[1197  993]
#  [ 797 1393]]

# %%
loss, accuracy, get_f1  = model_v.evaluate_generator(test_generator, verbose=True)
# Out:
# 438/438 [==============================] - 57s 130ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.593
# Test accuracy: 0.591
# Test F1: 0.591

# %%
accuracy, precision, recall, fscore = countStats(y_true_v, y_pred_v)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.591324200913242
# Precision: 0.5920615997195274
# Recall: 0.591324200913242
# F-score: 0.5905042018211235
