# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17515229246769745037
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3571842112732265441
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla ResNetu

IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0  ../data/Photos/photoshops/co20t8o_0.png         0
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg         0
# 2  ../data/Photos/photoshops/d23zitu_0.png         0
# 3  ../data/Photos/photoshops/cxevpq7_0.png         0
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg         0

# %%
df.shape
# Out:
# (21896, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0  ../data/Photos/photoshops/co20t8o_0.png         0
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg         0
# 2  ../data/Photos/photoshops/d23zitu_0.png         0
# 3  ../data/Photos/photoshops/cxevpq7_0.png         0
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg         0

# %%
X.head()
# Out:
#                                   filename
# 0  ../data/Photos/photoshops/co20t8o_0.png
# 1  ../data/Photos/photoshops/cb7k2h8_0.jpg
# 2  ../data/Photos/photoshops/d23zitu_0.png
# 3  ../data/Photos/photoshops/cxevpq7_0.png
# 4  ../data/Photos/photoshops/c7st1q3_0.jpg

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21896, 2)
# 	 train: (17516, 2)
# 	 test: (4380, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21896, 2)
# 	 train: (17516, 2)
# 	 test: (4380, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
# To Do

batch_size = 10
activation = 'relu'
loss_type = 'categorical_crossentropy'
optimizer = 'Adam'
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
 * losowa rotacja o 15 stopni
 * reskalowanie
 * przybliżenie
 * obrót horyzontalny
 * zakresy dla przesunieć wertykalnych i horyzontalnych
'''

from keras.applications.resnet_v2 import preprocess_input

data_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17516 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4380 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet_v2 import ResNet50V2

pre_trained_model_fn = ResNet50V2(include_top = False, pooling = 'avg', weights = 'imagenet')

for layer in pre_trained_model_fn.layers[:15]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[15:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dropout(dropout))
model_fn.add(BatchNormalization())
model_fn.add(Dense(2, activation='softmax'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Model)           (None, 2048)              23564800
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 24,090,882
# Trainable params: 23,977,474
# Non-trainable params: 113,408
# _________________________________________________________________

# %% [markdown]
# # ResNet bez żadnych wag wejściowych

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet_v2 import ResNet50V2

pre_trained_model_v = ResNet50V2(include_top = True, weights = None, classes=2)

model_v = Sequential()

model_v.add(pre_trained_model_v)

model_v.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Model)           (None, 2)                 23568898
# =================================================================
# Total params: 23,568,898
# Trainable params: 23,523,458
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P_v2.h5')
# Out:
# Epoch 1/50
#   48/1751 [..............................] - ETA: 13:58 - loss: 1.1210 - accuracy: 0.5063 - get_f1: 0.5062
# d:\programs\python37\lib\site-packages\PIL\Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 1751/1751 [==============================] - 486s 278ms/step - loss: 0.7439 - accuracy: 0.5089 - get_f1: 0.5089 - val_loss: 0.7155 - val_accuracy: 0.5000 - val_get_f1: 0.5000
#
# Epoch 00001: val_loss improved from inf to 0.71548, saving model to best.h5
# Epoch 2/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.7046 - accuracy: 0.5102 - get_f1: 0.5102 - val_loss: 0.6554 - val_accuracy: 0.5007 - val_get_f1: 0.5007
#
# Epoch 00002: val_loss improved from 0.71548 to 0.65541, saving model to best.h5
# Epoch 3/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6997 - accuracy: 0.5073 - get_f1: 0.5073 - val_loss: 0.6979 - val_accuracy: 0.5034 - val_get_f1: 0.5034
#
# Epoch 00003: val_loss did not improve from 0.65541
# Epoch 4/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.7011 - accuracy: 0.5057 - get_f1: 0.5057 - val_loss: 1.2331 - val_accuracy: 0.5203 - val_get_f1: 0.5203
#
# Epoch 00004: val_loss did not improve from 0.65541
# Epoch 5/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6981 - accuracy: 0.5138 - get_f1: 0.5139 - val_loss: 0.6766 - val_accuracy: 0.4963 - val_get_f1: 0.4963
#
# Epoch 00005: val_loss did not improve from 0.65541
# Epoch 6/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6947 - accuracy: 0.5260 - get_f1: 0.5261 - val_loss: 1.2484 - val_accuracy: 0.5308 - val_get_f1: 0.5308
#
# Epoch 00006: val_loss did not improve from 0.65541
# Epoch 7/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6904 - accuracy: 0.5468 - get_f1: 0.5468 - val_loss: 0.6903 - val_accuracy: 0.5457 - val_get_f1: 0.5457
#
# Epoch 00007: val_loss did not improve from 0.65541
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 8/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6867 - accuracy: 0.5490 - get_f1: 0.5490 - val_loss: 0.7398 - val_accuracy: 0.5432 - val_get_f1: 0.5432
#
# Epoch 00008: val_loss did not improve from 0.65541
# Epoch 9/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6845 - accuracy: 0.5566 - get_f1: 0.5567 - val_loss: 2.6336 - val_accuracy: 0.5530 - val_get_f1: 0.5530
#
# Epoch 00009: val_loss did not improve from 0.65541
# Epoch 10/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6813 - accuracy: 0.5616 - get_f1: 0.5616 - val_loss: 0.7655 - val_accuracy: 0.5612 - val_get_f1: 0.5612
#
# Epoch 00010: val_loss did not improve from 0.65541
# Epoch 11/50
# 1751/1751 [==============================] - 413s 236ms/step - loss: 0.6800 - accuracy: 0.5665 - get_f1: 0.5665 - val_loss: 0.6829 - val_accuracy: 0.5511 - val_get_f1: 0.5511
#
# Epoch 00011: val_loss did not improve from 0.65541
# Epoch 12/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6800 - accuracy: 0.5645 - get_f1: 0.5645 - val_loss: 1.2232 - val_accuracy: 0.5619 - val_get_f1: 0.5619
#
# Epoch 00012: val_loss did not improve from 0.65541
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 13/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6784 - accuracy: 0.5713 - get_f1: 0.5713 - val_loss: 0.5238 - val_accuracy: 0.5534 - val_get_f1: 0.5534
#
# Epoch 00013: val_loss improved from 0.65541 to 0.52385, saving model to best.h5
# Epoch 14/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6790 - accuracy: 0.5685 - get_f1: 0.5685 - val_loss: 0.8328 - val_accuracy: 0.5502 - val_get_f1: 0.5502
#
# Epoch 00014: val_loss did not improve from 0.52385
# Epoch 15/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6771 - accuracy: 0.5691 - get_f1: 0.5691 - val_loss: 0.6967 - val_accuracy: 0.5530 - val_get_f1: 0.5530
#
# Epoch 00015: val_loss did not improve from 0.52385
# Epoch 16/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6770 - accuracy: 0.5714 - get_f1: 0.5713 - val_loss: 0.7108 - val_accuracy: 0.5580 - val_get_f1: 0.5580
#
# Epoch 00016: val_loss did not improve from 0.52385
# Epoch 17/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6765 - accuracy: 0.5720 - get_f1: 0.5720 - val_loss: 0.7449 - val_accuracy: 0.5578 - val_get_f1: 0.5578
#
# Epoch 00017: val_loss did not improve from 0.52385
# Epoch 18/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6753 - accuracy: 0.5723 - get_f1: 0.5723 - val_loss: 0.5167 - val_accuracy: 0.5564 - val_get_f1: 0.5564
#
# Epoch 00018: val_loss improved from 0.52385 to 0.51669, saving model to best.h5
# Epoch 19/50
# 1751/1751 [==============================] - 412s 236ms/step - loss: 0.6781 - accuracy: 0.5691 - get_f1: 0.5691 - val_loss: 0.6670 - val_accuracy: 0.5582 - val_get_f1: 0.5582
#
# Epoch 00019: val_loss did not improve from 0.51669
# Epoch 20/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6777 - accuracy: 0.5679 - get_f1: 0.5679 - val_loss: 0.8360 - val_accuracy: 0.5553 - val_get_f1: 0.5553
#
# Epoch 00020: val_loss did not improve from 0.51669
# Epoch 21/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6762 - accuracy: 0.5699 - get_f1: 0.5699 - val_loss: 0.6552 - val_accuracy: 0.5584 - val_get_f1: 0.5584
#
# Epoch 00021: val_loss did not improve from 0.51669
# Epoch 22/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6768 - accuracy: 0.5689 - get_f1: 0.5689 - val_loss: 0.7943 - val_accuracy: 0.5655 - val_get_f1: 0.5655
#
# Epoch 00022: val_loss did not improve from 0.51669
# Epoch 23/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6763 - accuracy: 0.5708 - get_f1: 0.5707 - val_loss: 1.5095 - val_accuracy: 0.5632 - val_get_f1: 0.5632
#
# Epoch 00023: val_loss did not improve from 0.51669
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 24/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6752 - accuracy: 0.5754 - get_f1: 0.5754 - val_loss: 0.6474 - val_accuracy: 0.5651 - val_get_f1: 0.5651
#
# Epoch 00024: val_loss did not improve from 0.51669
# Epoch 25/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6760 - accuracy: 0.5743 - get_f1: 0.5743 - val_loss: 0.7591 - val_accuracy: 0.5619 - val_get_f1: 0.5619
#
# Epoch 00025: val_loss did not improve from 0.51669
# Epoch 26/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6749 - accuracy: 0.5744 - get_f1: 0.5744 - val_loss: 0.5565 - val_accuracy: 0.5582 - val_get_f1: 0.5582
#
# Epoch 00026: val_loss did not improve from 0.51669
# Epoch 27/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6770 - accuracy: 0.5661 - get_f1: 0.5661 - val_loss: 0.9060 - val_accuracy: 0.5646 - val_get_f1: 0.5646
#
# Epoch 00027: val_loss did not improve from 0.51669
# Epoch 28/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6762 - accuracy: 0.5762 - get_f1: 0.5762 - val_loss: 1.8643 - val_accuracy: 0.5589 - val_get_f1: 0.5589
#
# Epoch 00028: val_loss did not improve from 0.51669
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 29/50
# 1751/1751 [==============================] - 413s 236ms/step - loss: 0.6758 - accuracy: 0.5696 - get_f1: 0.5697 - val_loss: 0.6378 - val_accuracy: 0.5619 - val_get_f1: 0.5619
#
# Epoch 00029: val_loss did not improve from 0.51669
# Epoch 30/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6751 - accuracy: 0.5725 - get_f1: 0.5725 - val_loss: 0.6820 - val_accuracy: 0.5603 - val_get_f1: 0.5603
#
# Epoch 00030: val_loss did not improve from 0.51669
# Epoch 31/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6751 - accuracy: 0.5775 - get_f1: 0.5775 - val_loss: 0.9474 - val_accuracy: 0.5598 - val_get_f1: 0.5598
#
# Epoch 00031: val_loss did not improve from 0.51669
# Epoch 32/50
# 1751/1751 [==============================] - 412s 235ms/step - loss: 0.6763 - accuracy: 0.5716 - get_f1: 0.5717 - val_loss: 0.9783 - val_accuracy: 0.5623 - val_get_f1: 0.5623
#
# Epoch 00032: val_loss did not improve from 0.51669
# Epoch 33/50
# 1751/1751 [==============================] - 411s 235ms/step - loss: 0.6755 - accuracy: 0.5716 - get_f1: 0.5716 - val_loss: 0.6314 - val_accuracy: 0.5630 - val_get_f1: 0.5630
# Epoch 00033: val_loss did not improve from 0.51669
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00033: early stopping

# %%
'''
odświeżenie callbacków
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %%
model_v.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_v = model_v.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_v.load_weights('best.h5')

# Zapis
model_v.save('the_best_v_P_v2.h5')
# Out:
# Epoch 1/50
#   61/1751 [>.............................] - ETA: 10:28 - loss: 0.8006 - accuracy: 0.5492 - get_f1: 0.5492
# d:\programs\python37\lib\site-packages\PIL\Image.py:989: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 1751/1751 [==============================] - 443s 253ms/step - loss: 0.7148 - accuracy: 0.5187 - get_f1: 0.5187 - val_loss: 0.6425 - val_accuracy: 0.5167 - val_get_f1: 0.5167
#
# Epoch 00001: val_loss improved from inf to 0.64253, saving model to best.h5
# Epoch 2/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.7024 - accuracy: 0.5185 - get_f1: 0.5185 - val_loss: 0.6771 - val_accuracy: 0.5142 - val_get_f1: 0.5142
#
# Epoch 00002: val_loss did not improve from 0.64253
# Epoch 3/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.7004 - accuracy: 0.5175 - get_f1: 0.5174 - val_loss: 0.6874 - val_accuracy: 0.5265 - val_get_f1: 0.5265
#
# Epoch 00003: val_loss did not improve from 0.64253
# Epoch 4/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.7010 - accuracy: 0.5129 - get_f1: 0.5129 - val_loss: 0.7483 - val_accuracy: 0.5078 - val_get_f1: 0.5078
#
# Epoch 00004: val_loss did not improve from 0.64253
# Epoch 5/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6967 - accuracy: 0.5183 - get_f1: 0.5183 - val_loss: 0.7203 - val_accuracy: 0.5390 - val_get_f1: 0.5390
#
# Epoch 00005: val_loss did not improve from 0.64253
# Epoch 6/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6917 - accuracy: 0.5307 - get_f1: 0.5306 - val_loss: 0.6893 - val_accuracy: 0.5475 - val_get_f1: 0.5475
#
# Epoch 00006: val_loss did not improve from 0.64253
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6856 - accuracy: 0.5511 - get_f1: 0.5511 - val_loss: 0.6981 - val_accuracy: 0.5626 - val_get_f1: 0.5626
#
# Epoch 00007: val_loss did not improve from 0.64253
# Epoch 8/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6833 - accuracy: 0.5562 - get_f1: 0.5561 - val_loss: 0.6807 - val_accuracy: 0.5685 - val_get_f1: 0.5685
#
# Epoch 00008: val_loss did not improve from 0.64253
# Epoch 9/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6807 - accuracy: 0.5595 - get_f1: 0.5595 - val_loss: 0.6808 - val_accuracy: 0.5658 - val_get_f1: 0.5658
#
# Epoch 00009: val_loss did not improve from 0.64253
# Epoch 10/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6795 - accuracy: 0.5655 - get_f1: 0.5655 - val_loss: 0.6192 - val_accuracy: 0.5781 - val_get_f1: 0.5781
#
# Epoch 00010: val_loss improved from 0.64253 to 0.61916, saving model to best.h5
# Epoch 11/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6767 - accuracy: 0.5739 - get_f1: 0.5739 - val_loss: 0.6330 - val_accuracy: 0.5831 - val_get_f1: 0.5831
#
# Epoch 00011: val_loss did not improve from 0.61916
# Epoch 12/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6753 - accuracy: 0.5725 - get_f1: 0.5725 - val_loss: 0.6612 - val_accuracy: 0.5808 - val_get_f1: 0.5808
#
# Epoch 00012: val_loss did not improve from 0.61916
# Epoch 13/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6742 - accuracy: 0.5763 - get_f1: 0.5763 - val_loss: 0.6189 - val_accuracy: 0.5854 - val_get_f1: 0.5854
#
# Epoch 00013: val_loss improved from 0.61916 to 0.61891, saving model to best.h5
# Epoch 14/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6709 - accuracy: 0.5832 - get_f1: 0.5831 - val_loss: 0.7445 - val_accuracy: 0.5849 - val_get_f1: 0.5849
#
# Epoch 00014: val_loss did not improve from 0.61891
# Epoch 15/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6705 - accuracy: 0.5841 - get_f1: 0.5842 - val_loss: 0.6588 - val_accuracy: 0.5890 - val_get_f1: 0.5890
#
# Epoch 00015: val_loss did not improve from 0.61891
# Epoch 16/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6680 - accuracy: 0.5863 - get_f1: 0.5863 - val_loss: 0.7259 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00016: val_loss did not improve from 0.61891
# Epoch 17/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6662 - accuracy: 0.5868 - get_f1: 0.5868 - val_loss: 0.6231 - val_accuracy: 0.5854 - val_get_f1: 0.5854
#
# Epoch 00017: val_loss did not improve from 0.61891
# Epoch 18/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6641 - accuracy: 0.5961 - get_f1: 0.5961 - val_loss: 0.6777 - val_accuracy: 0.5865 - val_get_f1: 0.5865
#
# Epoch 00018: val_loss did not improve from 0.61891
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6622 - accuracy: 0.5955 - get_f1: 0.5954 - val_loss: 0.6548 - val_accuracy: 0.5904 - val_get_f1: 0.5904
#
# Epoch 00019: val_loss did not improve from 0.61891
# Epoch 20/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6610 - accuracy: 0.5991 - get_f1: 0.5990 - val_loss: 0.5397 - val_accuracy: 0.5888 - val_get_f1: 0.5888
#
# Epoch 00020: val_loss improved from 0.61891 to 0.53969, saving model to best.h5
# Epoch 21/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6617 - accuracy: 0.5979 - get_f1: 0.5979 - val_loss: 0.5951 - val_accuracy: 0.5884 - val_get_f1: 0.5884
#
# Epoch 00021: val_loss did not improve from 0.53969
# Epoch 22/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6594 - accuracy: 0.6035 - get_f1: 0.6034 - val_loss: 0.7177 - val_accuracy: 0.5893 - val_get_f1: 0.5893
#
# Epoch 00022: val_loss did not improve from 0.53969
# Epoch 23/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6606 - accuracy: 0.5937 - get_f1: 0.5937 - val_loss: 0.5726 - val_accuracy: 0.5888 - val_get_f1: 0.5888
#
# Epoch 00023: val_loss did not improve from 0.53969
# Epoch 24/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6610 - accuracy: 0.5981 - get_f1: 0.5982 - val_loss: 0.6627 - val_accuracy: 0.5906 - val_get_f1: 0.5906
#
# Epoch 00024: val_loss did not improve from 0.53969
# Epoch 25/50
# 1751/1751 [==============================] - 435s 249ms/step - loss: 0.6597 - accuracy: 0.6012 - get_f1: 0.6012 - val_loss: 0.6036 - val_accuracy: 0.5870 - val_get_f1: 0.5870
#
# Epoch 00025: val_loss did not improve from 0.53969
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 26/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6592 - accuracy: 0.6013 - get_f1: 0.6013 - val_loss: 0.5292 - val_accuracy: 0.5870 - val_get_f1: 0.5870
#
# Epoch 00026: val_loss improved from 0.53969 to 0.52922, saving model to best.h5
# Epoch 27/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6581 - accuracy: 0.6040 - get_f1: 0.6040 - val_loss: 0.6210 - val_accuracy: 0.5904 - val_get_f1: 0.5904
#
# Epoch 00027: val_loss did not improve from 0.52922
# Epoch 28/50
# 1751/1751 [==============================] - 433s 248ms/step - loss: 0.6578 - accuracy: 0.6021 - get_f1: 0.6021 - val_loss: 0.6675 - val_accuracy: 0.5900 - val_get_f1: 0.5900
#
# Epoch 00028: val_loss did not improve from 0.52922
# Epoch 29/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6590 - accuracy: 0.6005 - get_f1: 0.6005 - val_loss: 0.5323 - val_accuracy: 0.5865 - val_get_f1: 0.5865
#
# Epoch 00029: val_loss did not improve from 0.52922
# Epoch 30/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6605 - accuracy: 0.5953 - get_f1: 0.5954 - val_loss: 0.5154 - val_accuracy: 0.5893 - val_get_f1: 0.5893
#
# Epoch 00030: val_loss improved from 0.52922 to 0.51541, saving model to best.h5
# Epoch 31/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6607 - accuracy: 0.6002 - get_f1: 0.6002 - val_loss: 0.6119 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00031: val_loss did not improve from 0.51541
# Epoch 32/50
# 1751/1751 [==============================] - 435s 248ms/step - loss: 0.6595 - accuracy: 0.5972 - get_f1: 0.5972 - val_loss: 0.7210 - val_accuracy: 0.5874 - val_get_f1: 0.5874
#
# Epoch 00032: val_loss did not improve from 0.51541
# Epoch 33/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6589 - accuracy: 0.5969 - get_f1: 0.5969 - val_loss: 0.7890 - val_accuracy: 0.5872 - val_get_f1: 0.5872
# Epoch 00033: val_loss did not improve from 0.51541
# Epoch 34/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6579 - accuracy: 0.6048 - get_f1: 0.6047 - val_loss: 0.6753 - val_accuracy: 0.5934 - val_get_f1: 0.5934
#
# Epoch 00034: val_loss did not improve from 0.51541
# Epoch 35/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6590 - accuracy: 0.6008 - get_f1: 0.6007 - val_loss: 0.7716 - val_accuracy: 0.5870 - val_get_f1: 0.5870
#
# Epoch 00035: val_loss did not improve from 0.51541
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 36/50
# 1751/1751 [==============================] - 432s 247ms/step - loss: 0.6591 - accuracy: 0.5985 - get_f1: 0.5985 - val_loss: 0.6560 - val_accuracy: 0.5888 - val_get_f1: 0.5888
#
# Epoch 00036: val_loss did not improve from 0.51541
# Epoch 37/50
# 1751/1751 [==============================] - 433s 248ms/step - loss: 0.6571 - accuracy: 0.6071 - get_f1: 0.6072 - val_loss: 0.7640 - val_accuracy: 0.5920 - val_get_f1: 0.5920
#
# Epoch 00037: val_loss did not improve from 0.51541
# Epoch 38/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6606 - accuracy: 0.5984 - get_f1: 0.5984 - val_loss: 0.6072 - val_accuracy: 0.5886 - val_get_f1: 0.5886
#
# Epoch 00038: val_loss did not improve from 0.51541
# Epoch 39/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6586 - accuracy: 0.6013 - get_f1: 0.6014 - val_loss: 0.7388 - val_accuracy: 0.5881 - val_get_f1: 0.5881
#
# Epoch 00039: val_loss did not improve from 0.51541
# Epoch 40/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6600 - accuracy: 0.5989 - get_f1: 0.5990 - val_loss: 0.6184 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00040: val_loss did not improve from 0.51541
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 41/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6583 - accuracy: 0.6013 - get_f1: 0.6013 - val_loss: 0.6832 - val_accuracy: 0.5872 - val_get_f1: 0.5872
#
# Epoch 00041: val_loss did not improve from 0.51541
# Epoch 42/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6595 - accuracy: 0.6006 - get_f1: 0.6005 - val_loss: 0.7311 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00042: val_loss did not improve from 0.51541
# Epoch 43/50
# 1751/1751 [==============================] - 434s 248ms/step - loss: 0.6598 - accuracy: 0.5985 - get_f1: 0.5986 - val_loss: 0.5749 - val_accuracy: 0.5884 - val_get_f1: 0.5884
#
# Epoch 00043: val_loss did not improve from 0.51541
# Epoch 44/50
# 1751/1751 [==============================] - 435s 249ms/step - loss: 0.6583 - accuracy: 0.6050 - get_f1: 0.6050 - val_loss: 0.8757 - val_accuracy: 0.5886 - val_get_f1: 0.5886
#
# Epoch 00044: val_loss did not improve from 0.51541
# Epoch 45/50
# 1751/1751 [==============================] - 433s 247ms/step - loss: 0.6597 - accuracy: 0.5982 - get_f1: 0.5982 - val_loss: 0.6418 - val_accuracy: 0.5897 - val_get_f1: 0.5897
#
# Epoch 00045: val_loss did not improve from 0.51541
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 00045: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_v.history['loss'], color='b', label="Training loss")
ax1.plot(history_v.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_v.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_v.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_v.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_v.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_v.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_v.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_v.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None,
    'predict_v': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn predict_v
# 0  ../data/Photos/photoshops/clif8r8_0.jpg        0       None      None
# 1      ../data/Photos/originals/1e6vy8.jpg        1       None      None
# 2  ../data/Photos/photoshops/cab7bor_0.jpg        0       None      None
# 3  ../data/Photos/photoshops/c630wz4_0.jpg        0       None      None
# 4  ../data/Photos/photoshops/cks1bqs_0.png        0       None      None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4380 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)

predict_v = model_v.predict_generator(validate_generator, verbose=True)
# Out:
# 438/438 [==============================] - 56s 128ms/step
# 438/438 [==============================] - 57s 131ms/step

# %%
# Zamiana z one hot encodera na jedno wyjście
stats_df['predict_fn'] = numpy.argmax(predict_fn, axis=-1)
stats_df['predict_v'] = numpy.argmax(predict_v, axis=-1)

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn  predict_v
# 0  ../data/Photos/photoshops/clif8r8_0.jpg        0           1          1
# 1      ../data/Photos/originals/1e6vy8.jpg        1           0          0
# 2  ../data/Photos/photoshops/cab7bor_0.jpg        0           0          0
# 3  ../data/Photos/photoshops/c630wz4_0.jpg        0           1          1
# 4  ../data/Photos/photoshops/cks1bqs_0.png        0           0          0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
stats_df['predict_v'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

y_true_v = stats_df['category'].to_numpy().astype(int)
y_pred_v = stats_df['predict_v'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)
cm_v = confusion_matrix(y_true_v, y_pred_v)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1856  334]
#  [1609  581]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 438/438 [==============================] - 56s 129ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 1.12
# Test accuracy: 0.556
# Test F1: 0.556

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.556392694063927
# Precision: 0.5853074066188819
# Recall: 0.556392694063927
# F-score: 0.5153226805400719

# %%
plot_cm(cm_v, ['Originals', 'Photoshops'])

# %%
print(cm_v)
# Out:
# [[1243  947]
#  [ 852 1338]]

# %%
loss, accuracy, get_f1  = model_v.evaluate_generator(test_generator, verbose=True)
# Out:
# 438/438 [==============================] - 56s 128ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.65
# Test accuracy: 0.589
# Test F1: 0.589

# %%
accuracy, precision, recall, fscore = countStats(y_true_v, y_pred_v)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.5892694063926941
# Precision: 0.5894377046526323
# Recall: 0.5892694063926941
# F-score: 0.589076093687868
