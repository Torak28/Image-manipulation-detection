# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8413794507774664602
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4203055952215858328
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Casia'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla ResNetu

IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                             filename  category
# 0           ../data/Casia/originals/Au_sec_30147.jpg         1
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...         0
# 2           ../data/Casia/originals/Au_nat_30329.jpg         1
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...         0
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...         0

# %%
df.shape
# Out:
# (12614, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                             filename  category
# 0           ../data/Casia/originals/Au_sec_30147.jpg         1
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...         0
# 2           ../data/Casia/originals/Au_nat_30329.jpg         1
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...         0
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...         0

# %%
X.head()
# Out:
#                                             filename
# 0           ../data/Casia/originals/Au_sec_30147.jpg
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...
# 2           ../data/Casia/originals/Au_nat_30329.jpg
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (12614, 2)
# 	 train: (10091, 2)
# 	 test: (2523, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (12614, 2)
# 	 train: (10091, 2)
# 	 test: (2523, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
# To Do

batch_size = 10
activation = 'relu'
loss_type = 'categorical_crossentropy'
optimizer = 'Adam'
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
'''

from keras.applications.resnet import preprocess_input

data_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 10091 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 2523 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50

pre_trained_model_fn = ResNet50(include_top = False, pooling = 'avg', weights = 'imagenet')

for layer in pre_trained_model_fn.layers[:38]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[38:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Dropout(dropout))
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dense(2, activation='softmax'))

model_fn.summary()

print(len(pre_trained_model_fn.trainable_weights))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 24,112,770
# Trainable params: 23,832,834
# Non-trainable params: 279,936
# _________________________________________________________________
# 168

# %% [markdown]
# # ResNet bez żadnych wag wejściowych

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50

pre_trained_model_v = ResNet50(include_top = True, weights = None, classes=2)

model_v = Sequential()

model_v.add(pre_trained_model_v)

model_v.summary()

print(len(model_v.trainable_weights))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2)                 23591810
# =================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# _________________________________________________________________
# 214

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_C.h5')
# Out:
# Epoch 1/50
#  159/1009 [===>..........................] - ETA: 3:44 - loss: 0.7790 - accuracy: 0.6145 - get_f1: 0.6145
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# 1009/1009 [==============================] - 232s 230ms/step - loss: 0.6605 - accuracy: 0.6504 - get_f1: 0.6507 - val_loss: 1.4349 - val_accuracy: 0.4651 - val_get_f1: 0.4651
#
# Epoch 00001: val_loss improved from inf to 1.43495, saving model to best.h5
# Epoch 2/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.5949 - accuracy: 0.6870 - get_f1: 0.6873 - val_loss: 0.5712 - val_accuracy: 0.6522 - val_get_f1: 0.6522
#
# Epoch 00002: val_loss improved from 1.43495 to 0.57115, saving model to best.h5
# Epoch 3/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.5542 - accuracy: 0.7234 - get_f1: 0.7237 - val_loss: 0.3243 - val_accuracy: 0.6968 - val_get_f1: 0.6967
#
# Epoch 00003: val_loss improved from 0.57115 to 0.32432, saving model to best.h5
# Epoch 4/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.5417 - accuracy: 0.7292 - get_f1: 0.7294 - val_loss: 0.5752 - val_accuracy: 0.7139 - val_get_f1: 0.7138
#
# Epoch 00004: val_loss did not improve from 0.32432
# Epoch 5/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.5191 - accuracy: 0.7469 - get_f1: 0.7472 - val_loss: 0.9015 - val_accuracy: 0.6622 - val_get_f1: 0.6622
#
# Epoch 00005: val_loss did not improve from 0.32432
# Epoch 6/50
# 1009/1009 [==============================] - 209s 207ms/step - loss: 0.5029 - accuracy: 0.7555 - get_f1: 0.7557 - val_loss: 0.4071 - val_accuracy: 0.7250 - val_get_f1: 0.7249
#
# Epoch 00006: val_loss did not improve from 0.32432
# Epoch 7/50
# 1009/1009 [==============================] - 209s 207ms/step - loss: 0.4829 - accuracy: 0.7686 - get_f1: 0.7688 - val_loss: 0.6046 - val_accuracy: 0.7449 - val_get_f1: 0.7438
#
# Epoch 00007: val_loss did not improve from 0.32432
# Epoch 8/50
# 1009/1009 [==============================] - 208s 207ms/step - loss: 0.4661 - accuracy: 0.7785 - get_f1: 0.7787 - val_loss: 0.7427 - val_accuracy: 0.7286 - val_get_f1: 0.7275
#
# Epoch 00008: val_loss did not improve from 0.32432
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.4065 - accuracy: 0.8095 - get_f1: 0.8088 - val_loss: 0.7166 - val_accuracy: 0.6705 - val_get_f1: 0.6687
#
# Epoch 00009: val_loss did not improve from 0.32432
# Epoch 10/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3797 - accuracy: 0.8257 - get_f1: 0.8259 - val_loss: 1.2499 - val_accuracy: 0.6781 - val_get_f1: 0.6780
#
# Epoch 00010: val_loss did not improve from 0.32432
# Epoch 11/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3582 - accuracy: 0.8338 - get_f1: 0.8340 - val_loss: 2.2822 - val_accuracy: 0.6622 - val_get_f1: 0.6622
#
# Epoch 00011: val_loss did not improve from 0.32432
# Epoch 12/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3421 - accuracy: 0.8413 - get_f1: 0.8414 - val_loss: 2.0129 - val_accuracy: 0.6888 - val_get_f1: 0.6878
#
# Epoch 00012: val_loss did not improve from 0.32432
# Epoch 13/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3401 - accuracy: 0.8416 - get_f1: 0.8417 - val_loss: 1.3623 - val_accuracy: 0.6848 - val_get_f1: 0.6848
#
# Epoch 00013: val_loss did not improve from 0.32432
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 14/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3195 - accuracy: 0.8526 - get_f1: 0.8527 - val_loss: 2.3058 - val_accuracy: 0.6848 - val_get_f1: 0.6857
#
# Epoch 00014: val_loss did not improve from 0.32432
# Epoch 15/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3145 - accuracy: 0.8570 - get_f1: 0.8562 - val_loss: 0.7127 - val_accuracy: 0.6840 - val_get_f1: 0.6849
#
# Epoch 00015: val_loss did not improve from 0.32432
# Epoch 16/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3129 - accuracy: 0.8559 - get_f1: 0.8560 - val_loss: 1.0108 - val_accuracy: 0.6721 - val_get_f1: 0.6721
#
# Epoch 00016: val_loss did not improve from 0.32432
# Epoch 17/50
# 1009/1009 [==============================] - 209s 207ms/step - loss: 0.3123 - accuracy: 0.8563 - get_f1: 0.8564 - val_loss: 0.4902 - val_accuracy: 0.6884 - val_get_f1: 0.6893
#
# Epoch 00017: val_loss did not improve from 0.32432
# Epoch 18/50
# 1009/1009 [==============================] - 208s 206ms/step - loss: 0.3158 - accuracy: 0.8553 - get_f1: 0.8554 - val_loss: 2.6849 - val_accuracy: 0.6813 - val_get_f1: 0.6812
#
# Epoch 00018: val_loss did not improve from 0.32432
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 00018: early stopping

# %%
'''
odświeżenie callbacków
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %%
model_v.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_v = model_v.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_v.load_weights('best.h5')

# Zapis
model_v.save('the_best_v_C.h5')
# Out:
# Epoch 1/50
#  496/1009 [=============>................] - ETA: 2:26 - loss: 0.8437 - accuracy: 0.5534 - get_f1: 0.5542
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# 1009/1009 [==============================] - 295s 292ms/step - loss: 0.7637 - accuracy: 0.5774 - get_f1: 0.5778 - val_loss: 0.4307 - val_accuracy: 0.6044 - val_get_f1: 0.6044
#
# Epoch 00001: val_loss improved from inf to 0.43072, saving model to best.h5
# Epoch 2/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6912 - accuracy: 0.5952 - get_f1: 0.5955 - val_loss: 0.7567 - val_accuracy: 0.6188 - val_get_f1: 0.6198
#
# Epoch 00002: val_loss did not improve from 0.43072
# Epoch 3/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6733 - accuracy: 0.6000 - get_f1: 0.5995 - val_loss: 22.5254 - val_accuracy: 0.4270 - val_get_f1: 0.4267
#
# Epoch 00003: val_loss did not improve from 0.43072
# Epoch 4/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6780 - accuracy: 0.5966 - get_f1: 0.5969 - val_loss: 0.7405 - val_accuracy: 0.6140 - val_get_f1: 0.6132
#
# Epoch 00004: val_loss did not improve from 0.43072
# Epoch 5/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6635 - accuracy: 0.6091 - get_f1: 0.6094 - val_loss: 0.9185 - val_accuracy: 0.5782 - val_get_f1: 0.5784
#
# Epoch 00005: val_loss did not improve from 0.43072
# Epoch 6/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6678 - accuracy: 0.6023 - get_f1: 0.6027 - val_loss: 0.7893 - val_accuracy: 0.5909 - val_get_f1: 0.5902
#
# Epoch 00006: val_loss did not improve from 0.43072
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 7/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6482 - accuracy: 0.6162 - get_f1: 0.6166 - val_loss: 0.6203 - val_accuracy: 0.6259 - val_get_f1: 0.6261
#
# Epoch 00007: val_loss did not improve from 0.43072
# Epoch 8/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6440 - accuracy: 0.6271 - get_f1: 0.6266 - val_loss: 0.4513 - val_accuracy: 0.6387 - val_get_f1: 0.6388
#
# Epoch 00008: val_loss did not improve from 0.43072
# Epoch 9/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6393 - accuracy: 0.6376 - get_f1: 0.6380 - val_loss: 0.5898 - val_accuracy: 0.6470 - val_get_f1: 0.6462
#
# Epoch 00009: val_loss did not improve from 0.43072
# Epoch 10/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6358 - accuracy: 0.6418 - get_f1: 0.6421 - val_loss: 0.4987 - val_accuracy: 0.6478 - val_get_f1: 0.6479
#
# Epoch 00010: val_loss did not improve from 0.43072
# Epoch 11/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6306 - accuracy: 0.6472 - get_f1: 0.6475 - val_loss: 0.7879 - val_accuracy: 0.6741 - val_get_f1: 0.6750
#
# Epoch 00011: val_loss did not improve from 0.43072
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 12/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6266 - accuracy: 0.6567 - get_f1: 0.6570 - val_loss: 0.9319 - val_accuracy: 0.6586 - val_get_f1: 0.6586
#
# Epoch 00012: val_loss did not improve from 0.43072
# Epoch 13/50
# 1009/1009 [==============================] - 286s 283ms/step - loss: 0.6243 - accuracy: 0.6575 - get_f1: 0.6569 - val_loss: 0.5279 - val_accuracy: 0.6622 - val_get_f1: 0.6622
#
# Epoch 00013: val_loss did not improve from 0.43072
# Epoch 14/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6230 - accuracy: 0.6557 - get_f1: 0.6560 - val_loss: 0.8623 - val_accuracy: 0.6641 - val_get_f1: 0.6642
#
# Epoch 00014: val_loss did not improve from 0.43072
# Epoch 15/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6184 - accuracy: 0.6639 - get_f1: 0.6633 - val_loss: 0.7703 - val_accuracy: 0.6594 - val_get_f1: 0.6594
#
# Epoch 00015: val_loss did not improve from 0.43072
# Epoch 16/50
# 1009/1009 [==============================] - 282s 280ms/step - loss: 0.6164 - accuracy: 0.6656 - get_f1: 0.6659 - val_loss: 0.4166 - val_accuracy: 0.6749 - val_get_f1: 0.6758
#
# Epoch 00016: val_loss improved from 0.43072 to 0.41657, saving model to best.h5
# Epoch 17/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6155 - accuracy: 0.6625 - get_f1: 0.6628 - val_loss: 0.5795 - val_accuracy: 0.6709 - val_get_f1: 0.6700
#
# Epoch 00017: val_loss did not improve from 0.41657
# Epoch 18/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6136 - accuracy: 0.6650 - get_f1: 0.6653 - val_loss: 0.7922 - val_accuracy: 0.6570 - val_get_f1: 0.6570
#
# Epoch 00018: val_loss did not improve from 0.41657
# Epoch 19/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6107 - accuracy: 0.6675 - get_f1: 0.6678 - val_loss: 0.6743 - val_accuracy: 0.6582 - val_get_f1: 0.6591
#
# Epoch 00019: val_loss did not improve from 0.41657
# Epoch 20/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6104 - accuracy: 0.6722 - get_f1: 0.6716 - val_loss: 0.5145 - val_accuracy: 0.6705 - val_get_f1: 0.6705
#
# Epoch 00020: val_loss did not improve from 0.41657
# Epoch 21/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6101 - accuracy: 0.6671 - get_f1: 0.6674 - val_loss: 0.6927 - val_accuracy: 0.6677 - val_get_f1: 0.6659
#
# Epoch 00021: val_loss did not improve from 0.41657
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 22/50
# 1009/1009 [==============================] - 282s 280ms/step - loss: 0.6036 - accuracy: 0.6768 - get_f1: 0.6771 - val_loss: 0.6643 - val_accuracy: 0.6618 - val_get_f1: 0.6627
#
# Epoch 00022: val_loss did not improve from 0.41657
# Epoch 23/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6077 - accuracy: 0.6727 - get_f1: 0.6721 - val_loss: 0.5314 - val_accuracy: 0.6689 - val_get_f1: 0.6698
#
# Epoch 00023: val_loss did not improve from 0.41657
# Epoch 24/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6025 - accuracy: 0.6769 - get_f1: 0.6772 - val_loss: 0.4919 - val_accuracy: 0.6681 - val_get_f1: 0.6681
#
# Epoch 00024: val_loss did not improve from 0.41657
# Epoch 25/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6065 - accuracy: 0.6693 - get_f1: 0.6696 - val_loss: 0.5569 - val_accuracy: 0.6645 - val_get_f1: 0.6655
#
# Epoch 00025: val_loss did not improve from 0.41657
# Epoch 26/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6050 - accuracy: 0.6739 - get_f1: 0.6742 - val_loss: 0.4706 - val_accuracy: 0.6594 - val_get_f1: 0.6594
#
# Epoch 00026: val_loss did not improve from 0.41657
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 27/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6016 - accuracy: 0.6747 - get_f1: 0.6750 - val_loss: 0.6508 - val_accuracy: 0.6717 - val_get_f1: 0.6726
#
# Epoch 00027: val_loss did not improve from 0.41657
# Epoch 28/50
# 1009/1009 [==============================] - 283s 280ms/step - loss: 0.6038 - accuracy: 0.6716 - get_f1: 0.6719 - val_loss: 0.6242 - val_accuracy: 0.6709 - val_get_f1: 0.6718
#
# Epoch 00028: val_loss did not improve from 0.41657
# Epoch 29/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6038 - accuracy: 0.6759 - get_f1: 0.6762 - val_loss: 0.8146 - val_accuracy: 0.6661 - val_get_f1: 0.6671
#
# Epoch 00029: val_loss did not improve from 0.41657
# Epoch 30/50
# 1009/1009 [==============================] - 284s 281ms/step - loss: 0.6004 - accuracy: 0.6778 - get_f1: 0.6781 - val_loss: 0.5622 - val_accuracy: 0.6665 - val_get_f1: 0.6675
#
# Epoch 00030: val_loss did not improve from 0.41657
# Epoch 31/50
# 1009/1009 [==============================] - 283s 281ms/step - loss: 0.6036 - accuracy: 0.6739 - get_f1: 0.6742 - val_loss: 0.5782 - val_accuracy: 0.6610 - val_get_f1: 0.6610
#
# Epoch 00031: val_loss did not improve from 0.41657
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 00031: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_v.history['loss'], color='b', label="Training loss")
ax1.plot(history_v.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_v.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_v.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_v.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_v.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_v.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_v.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_v.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None,
    'predict_v': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                             filename category predict_fn  \
# 0           ../data/Casia/originals/Au_pla_30557.jpg        1       None
# 1  ../data/Casia/photoshops/Tp_S_NNN_M_N_sec00029...        0       None
# 2           ../data/Casia/originals/Au_sec_30622.jpg        1       None
# 3           ../data/Casia/originals/Au_art_20089.jpg        1       None
# 4           ../data/Casia/originals/Au_art_00019.jpg        1       None
#
#   predict_v
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 2523 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)

predict_v = model_v.predict_generator(validate_generator, verbose=True)
# Out:
# 253/253 [==============================] - 18s 70ms/step
# 253/253 [==============================] - 18s 70ms/step

# %%
# Zamiana z one hot encodera na jedno wyjście
stats_df['predict_fn'] = numpy.argmax(predict_fn, axis=-1)
stats_df['predict_v'] = numpy.argmax(predict_v, axis=-1)

# %%
stats_df.head()
# Out:
#                                             filename category  predict_fn  \
# 0           ../data/Casia/originals/Au_pla_30557.jpg        1           1
# 1  ../data/Casia/photoshops/Tp_S_NNN_M_N_sec00029...        0           1
# 2           ../data/Casia/originals/Au_sec_30622.jpg        1           1
# 3           ../data/Casia/originals/Au_art_20089.jpg        1           0
# 4           ../data/Casia/originals/Au_art_00019.jpg        1           1
#
#    predict_v
# 0          1
# 1          1
# 2          1
# 3          0
# 4          0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
stats_df['predict_v'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

y_true_v = stats_df['category'].to_numpy().astype(int)
y_pred_v = stats_df['predict_v'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)
cm_v = confusion_matrix(y_true_v, y_pred_v)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[ 494  530]
#  [ 233 1266]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 253/253 [==============================] - 17s 66ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.539
# Test accuracy: 0.698
# Test F1: 0.697

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6975822433610781
# Precision: 0.6945928244136689
# Recall: 0.6975822433610781
# F-score: 0.6855640421141516

# %%
plot_cm(cm_v, ['Originals', 'Photoshops'])

# %%
print(cm_v)
# Out:
# [[ 455  569]
#  [ 257 1242]]

# %%
loss, accuracy, get_f1  = model_v.evaluate_generator(test_generator, verbose=True)
# Out:
# 253/253 [==============================] - 17s 66ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.729
# Test accuracy: 0.673
# Test F1: 0.672

# %%
accuracy, precision, recall, fscore = countStats(y_true_v, y_pred_v)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6726119698771305
# Precision: 0.666829025575775
# Recall: 0.6726119698771305
# F-score: 0.6586220763711211
