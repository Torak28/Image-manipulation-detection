# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
Folder Casia:
 * '../data/Casia'
'''

dir_path = '../data/Casia'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla ResNetu

IMAGE_WIDTH=150
IMAGE_HEIGHT=150
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                             filename  category
# 0           ../data/Casia/originals/Au_sec_30147.jpg         1
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...         0
# 2           ../data/Casia/originals/Au_nat_30329.jpg         1
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...         0
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...         0

# %%
df.shape
# Out:
# (12614, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                             filename  category
# 0           ../data/Casia/originals/Au_sec_30147.jpg         1
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...         0
# 2           ../data/Casia/originals/Au_nat_30329.jpg         1
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...         0
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...         0

# %%
X.head()
# Out:
#                                             filename
# 0           ../data/Casia/originals/Au_sec_30147.jpg
# 1  ../data/Casia/photoshops/Tp_S_NRN_S_B_sec20014...
# 2           ../data/Casia/originals/Au_nat_30329.jpg
# 3  ../data/Casia/photoshops/Tp_D_NRN_S_N_sec00061...
# 4  ../data/Casia/photoshops/Tp_S_CRN_M_N_nat10164...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (12614, 2)
# 	 train: (10091, 2)
# 	 test: (2523, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (12614, 2)
# 	 train: (10091, 2)
# 	 test: (2523, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 10
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
# To Do

batch_size = 50
activation = 'relu'
loss_type = 'categorical_crossentropy'
optimizer = 'Adam'
dropout = 0.25
epochs = 50

# %% [markdown]
# # Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation=activation, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation=activation))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(128, (3, 3), activation=activation))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation=activation))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(dropout))
model.add(Dense(512, activation=activation))
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
 * losowa rotacja o 15 stopni
 * reskalowanie
 * przybliżenie
 * obrót horyzontalny
 * zakresy dla przesunieć wertykalnych i horyzontalnych
'''

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip = True,
    vertical_flip = True
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 10091 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 2523 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = train_datagen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fit

# %%
model.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history = model.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps= test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model.load_weights('best.h5')

# Zapis
model.save('the_best_P.h5')
# Out:
# Epoch 1/50
#  66/201 [========>.....................] - ETA: 2:19 - loss: 0.6890 - accuracy: 0.5773 - get_f1: 0.5773
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# d:\programs\python37\lib\site-packages\PIL\TiffImagePlugin.py:784: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# 201/201 [==============================] - 209s 1s/step - loss: 0.6652 - accuracy: 0.5904 - get_f1: 0.5904 - val_loss: 0.6632 - val_accuracy: 0.6040 - val_get_f1: 0.6040
#
# Epoch 00001: val_loss improved from inf to 0.66317, saving model to best.h5
# Epoch 2/50
# 201/201 [==============================] - 20s 98ms/step - loss: 0.6457 - accuracy: 0.6197 - get_f1: 0.6197 - val_loss: 0.6098 - val_accuracy: 0.6300 - val_get_f1: 0.6298
#
# Epoch 00002: val_loss improved from 0.66317 to 0.60979, saving model to best.h5
# Epoch 3/50
# 201/201 [==============================] - 20s 98ms/step - loss: 0.6442 - accuracy: 0.6259 - get_f1: 0.6259 - val_loss: 0.6185 - val_accuracy: 0.6110 - val_get_f1: 0.6119
#
# Epoch 00003: val_loss did not improve from 0.60979
# Epoch 4/50
# 201/201 [==============================] - 19s 97ms/step - loss: 0.6356 - accuracy: 0.6284 - get_f1: 0.6284 - val_loss: 0.6953 - val_accuracy: 0.6417 - val_get_f1: 0.6433
#
# Epoch 00004: val_loss did not improve from 0.60979
# Epoch 5/50
# 201/201 [==============================] - 19s 97ms/step - loss: 0.6341 - accuracy: 0.6362 - get_f1: 0.6363 - val_loss: 0.6383 - val_accuracy: 0.6264 - val_get_f1: 0.6252
#
# Epoch 00005: val_loss did not improve from 0.60979
# Epoch 6/50
# 201/201 [==============================] - 20s 99ms/step - loss: 0.6197 - accuracy: 0.6545 - get_f1: 0.6546 - val_loss: 0.5576 - val_accuracy: 0.6721 - val_get_f1: 0.6718
#
# Epoch 00006: val_loss improved from 0.60979 to 0.55756, saving model to best.h5
# Epoch 7/50
# 201/201 [==============================] - 19s 96ms/step - loss: 0.6018 - accuracy: 0.6787 - get_f1: 0.6787 - val_loss: 0.5091 - val_accuracy: 0.6777 - val_get_f1: 0.6770
#
# Epoch 00007: val_loss improved from 0.55756 to 0.50906, saving model to best.h5
# Epoch 8/50
# 201/201 [==============================] - 19s 96ms/step - loss: 0.5809 - accuracy: 0.6936 - get_f1: 0.6935 - val_loss: 0.5761 - val_accuracy: 0.6943 - val_get_f1: 0.6943
#
# Epoch 00008: val_loss did not improve from 0.50906
# Epoch 9/50
# 201/201 [==============================] - 19s 95ms/step - loss: 0.5612 - accuracy: 0.7106 - get_f1: 0.7105 - val_loss: 0.5450 - val_accuracy: 0.7064 - val_get_f1: 0.7049
#
# Epoch 00009: val_loss did not improve from 0.50906
# Epoch 10/50
# 201/201 [==============================] - 19s 94ms/step - loss: 0.5477 - accuracy: 0.7253 - get_f1: 0.7253 - val_loss: 0.5130 - val_accuracy: 0.7040 - val_get_f1: 0.7039
#
# Epoch 00010: val_loss did not improve from 0.50906
# Epoch 11/50
# 201/201 [==============================] - 19s 95ms/step - loss: 0.5302 - accuracy: 0.7339 - get_f1: 0.7338 - val_loss: 0.5862 - val_accuracy: 0.7258 - val_get_f1: 0.7260
#
# Epoch 00011: val_loss did not improve from 0.50906
# Epoch 12/50
# 201/201 [==============================] - 19s 94ms/step - loss: 0.5110 - accuracy: 0.7486 - get_f1: 0.7487 - val_loss: 0.5324 - val_accuracy: 0.7465 - val_get_f1: 0.7469
#
# Epoch 00012: val_loss did not improve from 0.50906
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/50
# 201/201 [==============================] - 19s 93ms/step - loss: 0.4698 - accuracy: 0.7781 - get_f1: 0.7780 - val_loss: 0.4470 - val_accuracy: 0.7675 - val_get_f1: 0.7667
#
# Epoch 00013: val_loss improved from 0.50906 to 0.44701, saving model to best.h5
# Epoch 14/50
# 201/201 [==============================] - 19s 93ms/step - loss: 0.4597 - accuracy: 0.7830 - get_f1: 0.7830 - val_loss: 0.4782 - val_accuracy: 0.7497 - val_get_f1: 0.7496
#
# Epoch 00014: val_loss did not improve from 0.44701
# Epoch 15/50
# 201/201 [==============================] - 19s 93ms/step - loss: 0.4502 - accuracy: 0.7896 - get_f1: 0.7895 - val_loss: 0.5247 - val_accuracy: 0.7776 - val_get_f1: 0.7767
#
# Epoch 00015: val_loss did not improve from 0.44701
# Epoch 16/50
# 201/201 [==============================] - 18s 91ms/step - loss: 0.4421 - accuracy: 0.7941 - get_f1: 0.7941 - val_loss: 0.4748 - val_accuracy: 0.7796 - val_get_f1: 0.7801
#
# Epoch 00016: val_loss did not improve from 0.44701
# Epoch 17/50
# 201/201 [==============================] - 19s 93ms/step - loss: 0.4348 - accuracy: 0.8005 - get_f1: 0.8005 - val_loss: 0.4675 - val_accuracy: 0.7784 - val_get_f1: 0.7789
#
# Epoch 00017: val_loss did not improve from 0.44701
# Epoch 18/50
# 201/201 [==============================] - 18s 92ms/step - loss: 0.4271 - accuracy: 0.7985 - get_f1: 0.7986 - val_loss: 0.4526 - val_accuracy: 0.7918 - val_get_f1: 0.7917
#
# Epoch 00018: val_loss did not improve from 0.44701
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 19/50
# 201/201 [==============================] - 19s 92ms/step - loss: 0.4205 - accuracy: 0.8058 - get_f1: 0.8058 - val_loss: 0.3432 - val_accuracy: 0.7966 - val_get_f1: 0.7983
#
# Epoch 00019: val_loss improved from 0.44701 to 0.34318, saving model to best.h5
# Epoch 20/50
# 201/201 [==============================] - 19s 97ms/step - loss: 0.4139 - accuracy: 0.8083 - get_f1: 0.8083 - val_loss: 0.4638 - val_accuracy: 0.7861 - val_get_f1: 0.7865
#
# Epoch 00020: val_loss did not improve from 0.34318
# Epoch 21/50
# 201/201 [==============================] - 19s 94ms/step - loss: 0.4182 - accuracy: 0.8056 - get_f1: 0.8056 - val_loss: 0.4868 - val_accuracy: 0.7873 - val_get_f1: 0.7873
#
# Epoch 00021: val_loss did not improve from 0.34318
# Epoch 22/50
# 201/201 [==============================] - 20s 97ms/step - loss: 0.4160 - accuracy: 0.8089 - get_f1: 0.8090 - val_loss: 0.3181 - val_accuracy: 0.7994 - val_get_f1: 0.7997
#
# Epoch 00022: val_loss improved from 0.34318 to 0.31806, saving model to best.h5
# Epoch 23/50
# 201/201 [==============================] - 20s 100ms/step - loss: 0.4191 - accuracy: 0.8048 - get_f1: 0.8049 - val_loss: 0.5106 - val_accuracy: 0.7978 - val_get_f1: 0.7986
#
# Epoch 00023: val_loss did not improve from 0.31806
# Epoch 24/50
# 201/201 [==============================] - 19s 97ms/step - loss: 0.4156 - accuracy: 0.8059 - get_f1: 0.8059 - val_loss: 0.4679 - val_accuracy: 0.8011 - val_get_f1: 0.7999
#
# Epoch 00024: val_loss did not improve from 0.31806
# Epoch 25/50
# 201/201 [==============================] - 19s 96ms/step - loss: 0.4081 - accuracy: 0.8148 - get_f1: 0.8149 - val_loss: 0.4408 - val_accuracy: 0.7934 - val_get_f1: 0.7933
#
# Epoch 00025: val_loss did not improve from 0.31806
# Epoch 26/50
# 201/201 [==============================] - 20s 99ms/step - loss: 0.4134 - accuracy: 0.8116 - get_f1: 0.8115 - val_loss: 0.3700 - val_accuracy: 0.7946 - val_get_f1: 0.7949
#
# Epoch 00026: val_loss did not improve from 0.31806
# Epoch 27/50
# 201/201 [==============================] - 19s 92ms/step - loss: 0.4162 - accuracy: 0.8071 - get_f1: 0.8071 - val_loss: 0.5694 - val_accuracy: 0.7825 - val_get_f1: 0.7829
#
# Epoch 00027: val_loss did not improve from 0.31806
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 28/50
# 201/201 [==============================] - 18s 91ms/step - loss: 0.4086 - accuracy: 0.8104 - get_f1: 0.8104 - val_loss: 0.4380 - val_accuracy: 0.8047 - val_get_f1: 0.8040
#
# Epoch 00028: val_loss did not improve from 0.31806
# Epoch 29/50
# 201/201 [==============================] - 18s 92ms/step - loss: 0.4129 - accuracy: 0.8126 - get_f1: 0.8125 - val_loss: 0.5530 - val_accuracy: 0.7938 - val_get_f1: 0.7946
#
# Epoch 00029: val_loss did not improve from 0.31806
# Epoch 30/50
# 201/201 [==============================] - 18s 92ms/step - loss: 0.4113 - accuracy: 0.8097 - get_f1: 0.8097 - val_loss: 0.3989 - val_accuracy: 0.7966 - val_get_f1: 0.7969
#
# Epoch 00030: val_loss did not improve from 0.31806
# Epoch 31/50
# 201/201 [==============================] - 18s 91ms/step - loss: 0.4078 - accuracy: 0.8108 - get_f1: 0.8107 - val_loss: 0.5031 - val_accuracy: 0.7881 - val_get_f1: 0.7881
#
# Epoch 00031: val_loss did not improve from 0.31806
# Epoch 32/50
# 201/201 [==============================] - 18s 91ms/step - loss: 0.4119 - accuracy: 0.8082 - get_f1: 0.8082 - val_loss: 0.4517 - val_accuracy: 0.7865 - val_get_f1: 0.7874
#
# Epoch 00032: val_loss did not improve from 0.31806
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 00032: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history.history['get_f1'], color='b', label="Training f1")
ax3.plot(history.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                             filename category predict
# 0  ../data/Casia/photoshops/Tp_D_NRN_S_N_cha00062...        0    None
# 1           ../data/Casia/originals/Au_arc_30208.jpg        1    None
# 2  ../data/Casia/photoshops/Tp_D_NRN_M_N_nat00002...        0    None
# 3           ../data/Casia/originals/Au_nat_30191.jpg        1    None
# 4           ../data/Casia/originals/Au_cha_10143.jpg        1    None

# %%
validate_datagen = ImageDataGenerator(rescale=1./255)

validate_generator = validate_datagen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 2523 validated image filenames.

# %%
predict = model.predict_generator(validate_generator, verbose=True)
# Out:
# 51/51 [==============================] - 4s 74ms/step

# %%
# Zamiana z one hot encodera na jedno wyjście
stats_df['predict'] = numpy.argmax(predict, axis=-1)

# %%
stats_df.head()
# Out:
#                                             filename category  predict
# 0  ../data/Casia/photoshops/Tp_D_NRN_S_N_cha00062...        0        0
# 1           ../data/Casia/originals/Au_arc_30208.jpg        1        1
# 2  ../data/Casia/photoshops/Tp_D_NRN_M_N_nat00002...        0        1
# 3           ../data/Casia/originals/Au_nat_30191.jpg        1        1
# 4           ../data/Casia/originals/Au_cha_10143.jpg        1        0

# %%
stats_df['predict'].value_counts().plot.bar()

# %%
y_true = stats_df['category'].to_numpy().astype(int)
y_pred = stats_df['predict'].to_numpy().astype(int)

# %%
 cm = confusion_matrix(y_true, y_pred)

# %%
plot_cm(cm, ['Originals', 'Photoshops'])

# %%
print(cm)
# Out:
# [[ 861  163]
#  [ 351 1148]]

# %%
accuracy, precision, recall, fscore = countStats(y_true, y_pred)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.796274276654776
# Precision: 0.8085893861632072
# Recall: 0.796274276654776
# F-score: 0.798023750666072

# %%
loss, accuracy, get_f1  = model.evaluate_generator(test_generator, verbose=True)
# Out:
# 51/51 [==============================] - 4s 74ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.541
# Test accuracy: 0.796
# Test F1: 0.795
