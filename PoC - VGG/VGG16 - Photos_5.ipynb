# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2308931528808871757
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5575094756705494645
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla VGG

IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
df.shape
# Out:
# (21758, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
X.head()
# Out:
#                                   filename
# 0      ../data/Photos/originals/7ak2w6.jpg
# 1      ../data/Photos/originals/27lsoy.jpg
# 2      ../data/Photos/originals/7g0q9a.jpg
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg
# 4      ../data/Photos/originals/4ioqrn.jpg

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
from keras import optimizers

batch_size = 16
activation = 'relu'
loss_type = 'binary_crossentropy'
optimizer = optimizers.RMSprop(lr=2e-5)
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
'''

from keras.applications.vgg16 import preprocess_input

data_gen = ImageDataGenerator(
#     preprocessing_function=preprocess_input
    rescale=1./255,
#     zoom_range=[0, 0.2],
    horizontal_flip=True,
    vertical_flip=True
)

data_test_gen = ImageDataGenerator(
    rescale=1./255
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17406 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_test_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4352 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50
from keras.applications import VGG16

pre_trained_model_fn = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))

for layer in pre_trained_model_fn.layers[:5]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[5:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Flatten())
model_fn.add(Dropout(dropout))
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dense(1, activation='sigmoid'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 21,025,153
# Non-trainable params: 112,576
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P.h5')
# Out:
# Epoch 1/50
# 1087/1087 [==============================] - 468s 431ms/step - loss: 0.6882 - accuracy: 0.5611 - get_f1: 0.5359 - val_loss: 0.7206 - val_accuracy: 0.5938 - val_get_f1: 0.6668
#
# Epoch 00001: val_loss improved from inf to 0.72062, saving model to best.h5
# Epoch 2/50
# 1087/1087 [==============================] - 314s 289ms/step - loss: 0.6684 - accuracy: 0.5971 - get_f1: 0.5891 - val_loss: 0.5781 - val_accuracy: 0.6137 - val_get_f1: 0.6712
#
# Epoch 00002: val_loss improved from 0.72062 to 0.57812, saving model to best.h5
# Epoch 3/50
# 1087/1087 [==============================] - 332s 305ms/step - loss: 0.6651 - accuracy: 0.5971 - get_f1: 0.5835 - val_loss: 0.6392 - val_accuracy: 0.5692 - val_get_f1: 0.3974
#
# Epoch 00003: val_loss did not improve from 0.57812
# Epoch 4/50
# 1087/1087 [==============================] - 327s 301ms/step - loss: 0.6645 - accuracy: 0.6021 - get_f1: 0.5855 - val_loss: 0.5820 - val_accuracy: 0.5878 - val_get_f1: 0.6712
#
# Epoch 00004: val_loss did not improve from 0.57812
# Epoch 5/50
# 1087/1087 [==============================] - 288s 265ms/step - loss: 0.6626 - accuracy: 0.6075 - get_f1: 0.5897 - val_loss: 0.7296 - val_accuracy: 0.6062 - val_get_f1: 0.5840
#
# Epoch 00005: val_loss did not improve from 0.57812
# Epoch 6/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6683 - accuracy: 0.5930 - get_f1: 0.5767 - val_loss: 0.6309 - val_accuracy: 0.5551 - val_get_f1: 0.3043
#
# Epoch 00006: val_loss did not improve from 0.57812
# Epoch 7/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6746 - accuracy: 0.5957 - get_f1: 0.5718 - val_loss: 0.7659 - val_accuracy: 0.5935 - val_get_f1: 0.5300
#
# Epoch 00007: val_loss did not improve from 0.57812
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# Epoch 8/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6470 - accuracy: 0.6173 - get_f1: 0.6114 - val_loss: 0.5549 - val_accuracy: 0.6094 - val_get_f1: 0.5616
#
# Epoch 00008: val_loss improved from 0.57812 to 0.55492, saving model to best.h5
# Epoch 9/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6521 - accuracy: 0.6213 - get_f1: 0.6223 - val_loss: 0.6322 - val_accuracy: 0.6087 - val_get_f1: 0.5532
#
# Epoch 00009: val_loss did not improve from 0.55492
# Epoch 10/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6480 - accuracy: 0.6224 - get_f1: 0.6175 - val_loss: 0.5474 - val_accuracy: 0.6160 - val_get_f1: 0.6025
#
# Epoch 00010: val_loss improved from 0.55492 to 0.54741, saving model to best.h5
# Epoch 11/50
# 1087/1087 [==============================] - 285s 263ms/step - loss: 0.6472 - accuracy: 0.6266 - get_f1: 0.6264 - val_loss: 0.6524 - val_accuracy: 0.6183 - val_get_f1: 0.5993
#
# Epoch 00011: val_loss did not improve from 0.54741
# Epoch 12/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6477 - accuracy: 0.6225 - get_f1: 0.6214 - val_loss: 0.7004 - val_accuracy: 0.6131 - val_get_f1: 0.5714
#
# Epoch 00012: val_loss did not improve from 0.54741
# Epoch 13/50
# 1087/1087 [==============================] - 286s 264ms/step - loss: 0.6457 - accuracy: 0.6277 - get_f1: 0.6270 - val_loss: 0.7641 - val_accuracy: 0.5912 - val_get_f1: 0.4874
#
# Epoch 00013: val_loss did not improve from 0.54741
# Epoch 14/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6431 - accuracy: 0.6242 - get_f1: 0.6236 - val_loss: 0.7032 - val_accuracy: 0.6248 - val_get_f1: 0.6229
#
# Epoch 00014: val_loss did not improve from 0.54741
# Epoch 15/50
# 1087/1087 [==============================] - 289s 266ms/step - loss: 0.6485 - accuracy: 0.6227 - get_f1: 0.6263 - val_loss: 0.7549 - val_accuracy: 0.6140 - val_get_f1: 0.6556
#
# Epoch 00015: val_loss did not improve from 0.54741
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.9999999949504855e-07.
# Epoch 16/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6439 - accuracy: 0.6265 - get_f1: 0.6321 - val_loss: 0.5933 - val_accuracy: 0.6151 - val_get_f1: 0.5921
#
# Epoch 00016: val_loss did not improve from 0.54741
# Epoch 17/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6459 - accuracy: 0.6263 - get_f1: 0.6271 - val_loss: 0.6226 - val_accuracy: 0.6172 - val_get_f1: 0.6074
#
# Epoch 00017: val_loss did not improve from 0.54741
# Epoch 18/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6456 - accuracy: 0.6252 - get_f1: 0.6250 - val_loss: 0.7311 - val_accuracy: 0.6190 - val_get_f1: 0.6255
#
# Epoch 00018: val_loss did not improve from 0.54741
# Epoch 19/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6466 - accuracy: 0.6304 - get_f1: 0.6330 - val_loss: 0.6308 - val_accuracy: 0.6202 - val_get_f1: 0.6139
#
# Epoch 00019: val_loss did not improve from 0.54741
# Epoch 20/50
# 1087/1087 [==============================] - 285s 263ms/step - loss: 0.6419 - accuracy: 0.6335 - get_f1: 0.6376 - val_loss: 0.6789 - val_accuracy: 0.6167 - val_get_f1: 0.6059
#
# Epoch 00020: val_loss did not improve from 0.54741
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.000000023372195e-08.
# Epoch 21/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6419 - accuracy: 0.6303 - get_f1: 0.6330 - val_loss: 0.7295 - val_accuracy: 0.6186 - val_get_f1: 0.6083
#
# Epoch 00021: val_loss did not improve from 0.54741
# Epoch 22/50
# 1087/1087 [==============================] - 285s 263ms/step - loss: 0.6409 - accuracy: 0.6294 - get_f1: 0.6325 - val_loss: 0.6534 - val_accuracy: 0.6193 - val_get_f1: 0.6121
#
# Epoch 00022: val_loss did not improve from 0.54741
# Epoch 23/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6441 - accuracy: 0.6345 - get_f1: 0.6346 - val_loss: 0.6711 - val_accuracy: 0.6190 - val_get_f1: 0.6117
#
# Epoch 00023: val_loss did not improve from 0.54741
# Epoch 24/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6380 - accuracy: 0.6312 - get_f1: 0.6342 - val_loss: 0.5958 - val_accuracy: 0.6176 - val_get_f1: 0.6096
#
# Epoch 00024: val_loss did not improve from 0.54741
# Epoch 25/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6396 - accuracy: 0.6311 - get_f1: 0.6325 - val_loss: 0.5027 - val_accuracy: 0.6176 - val_get_f1: 0.6088
#
# Epoch 00025: val_loss improved from 0.54741 to 0.50269, saving model to best.h5
# Epoch 26/50
# 1087/1087 [==============================] - 284s 262ms/step - loss: 0.6389 - accuracy: 0.6317 - get_f1: 0.6372 - val_loss: 0.5679 - val_accuracy: 0.6176 - val_get_f1: 0.6082
#
# Epoch 00026: val_loss did not improve from 0.50269
# Epoch 27/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6403 - accuracy: 0.6298 - get_f1: 0.6318 - val_loss: 0.6075 - val_accuracy: 0.6170 - val_get_f1: 0.6052
#
# Epoch 00027: val_loss did not improve from 0.50269
# Epoch 28/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6434 - accuracy: 0.6302 - get_f1: 0.6348 - val_loss: 2.8264 - val_accuracy: 0.6179 - val_get_f1: 0.6058
#
# Epoch 00028: val_loss did not improve from 0.50269
# Epoch 29/50
# 1087/1087 [==============================] - 284s 262ms/step - loss: 0.6415 - accuracy: 0.6338 - get_f1: 0.6339 - val_loss: 0.6251 - val_accuracy: 0.6193 - val_get_f1: 0.6105
#
# Epoch 00029: val_loss did not improve from 0.50269
# Epoch 30/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6460 - accuracy: 0.6275 - get_f1: 0.6267 - val_loss: 0.5396 - val_accuracy: 0.6174 - val_get_f1: 0.6067
#
# Epoch 00030: val_loss did not improve from 0.50269
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.9999999878450583e-09.
# Epoch 31/50
# 1087/1087 [==============================] - 284s 262ms/step - loss: 0.6455 - accuracy: 0.6301 - get_f1: 0.6318 - val_loss: 0.6888 - val_accuracy: 0.6174 - val_get_f1: 0.6059
#
# Epoch 00031: val_loss did not improve from 0.50269
# Epoch 32/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6420 - accuracy: 0.6339 - get_f1: 0.6360 - val_loss: 0.5262 - val_accuracy: 0.6174 - val_get_f1: 0.6058
#
# Epoch 00032: val_loss did not improve from 0.50269
# Epoch 33/50
# 1087/1087 [==============================] - 285s 263ms/step - loss: 0.6414 - accuracy: 0.6289 - get_f1: 0.6305 - val_loss: 2.8457 - val_accuracy: 0.6174 - val_get_f1: 0.6075
#
# Epoch 00033: val_loss did not improve from 0.50269
# Epoch 34/50
# 1087/1087 [==============================] - 284s 261ms/step - loss: 0.6401 - accuracy: 0.6306 - get_f1: 0.6320 - val_loss: 0.5633 - val_accuracy: 0.6172 - val_get_f1: 0.6103
#
# Epoch 00034: val_loss did not improve from 0.50269
# Epoch 35/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6429 - accuracy: 0.6316 - get_f1: 0.6326 - val_loss: 0.4309 - val_accuracy: 0.6172 - val_get_f1: 0.6090
#
# Epoch 00035: val_loss improved from 0.50269 to 0.43090, saving model to best.h5
# Epoch 36/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6415 - accuracy: 0.6340 - get_f1: 0.6344 - val_loss: 0.6920 - val_accuracy: 0.6170 - val_get_f1: 0.6075
#
# Epoch 00036: val_loss did not improve from 0.43090
# Epoch 37/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6453 - accuracy: 0.6320 - get_f1: 0.6347 - val_loss: 0.5781 - val_accuracy: 0.6170 - val_get_f1: 0.6084
#
# Epoch 00037: val_loss did not improve from 0.43090
# Epoch 38/50
# 1087/1087 [==============================] - 284s 261ms/step - loss: 0.6438 - accuracy: 0.6298 - get_f1: 0.6349 - val_loss: 0.5512 - val_accuracy: 0.6170 - val_get_f1: 0.6050
#
# Epoch 00038: val_loss did not improve from 0.43090
# Epoch 39/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6415 - accuracy: 0.6306 - get_f1: 0.6334 - val_loss: 0.6372 - val_accuracy: 0.6172 - val_get_f1: 0.6068
#
# Epoch 00039: val_loss did not improve from 0.43090
# Epoch 40/50
# 1087/1087 [==============================] - 284s 261ms/step - loss: 0.6408 - accuracy: 0.6309 - get_f1: 0.6334 - val_loss: 0.6670 - val_accuracy: 0.6172 - val_get_f1: 0.6034
#
# Epoch 00040: val_loss did not improve from 0.43090
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.999999943436137e-10.
# Epoch 41/50
# 1087/1087 [==============================] - 289s 266ms/step - loss: 0.6412 - accuracy: 0.6297 - get_f1: 0.6316 - val_loss: 0.6599 - val_accuracy: 0.6172 - val_get_f1: 0.6082
#
# Epoch 00041: val_loss did not improve from 0.43090
# Epoch 42/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6429 - accuracy: 0.6317 - get_f1: 0.6355 - val_loss: 0.6579 - val_accuracy: 0.6172 - val_get_f1: 0.6060
#
# Epoch 00042: val_loss did not improve from 0.43090
# Epoch 43/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6406 - accuracy: 0.6326 - get_f1: 0.6333 - val_loss: 0.7641 - val_accuracy: 0.6172 - val_get_f1: 0.6071
#
# Epoch 00043: val_loss did not improve from 0.43090
# Epoch 44/50
# 1087/1087 [==============================] - 284s 262ms/step - loss: 0.6416 - accuracy: 0.6307 - get_f1: 0.6335 - val_loss: 0.6232 - val_accuracy: 0.6172 - val_get_f1: 0.6048
#
# Epoch 00044: val_loss did not improve from 0.43090
# Epoch 45/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6417 - accuracy: 0.6298 - get_f1: 0.6307 - val_loss: 0.6436 - val_accuracy: 0.6172 - val_get_f1: 0.6067
#
# Epoch 00045: val_loss did not improve from 0.43090
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.999999887924986e-11.
# Epoch 46/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6387 - accuracy: 0.6302 - get_f1: 0.6349 - val_loss: 0.6503 - val_accuracy: 0.6172 - val_get_f1: 0.6072
#
# Epoch 00046: val_loss did not improve from 0.43090
# Epoch 47/50
# 1087/1087 [==============================] - 284s 261ms/step - loss: 0.6377 - accuracy: 0.6329 - get_f1: 0.6362 - val_loss: 0.6125 - val_accuracy: 0.6172 - val_get_f1: 0.6055
#
# Epoch 00047: val_loss did not improve from 0.43090
# Epoch 48/50
# 1087/1087 [==============================] - 287s 264ms/step - loss: 0.6390 - accuracy: 0.6309 - get_f1: 0.6334 - val_loss: 0.7719 - val_accuracy: 0.6172 - val_get_f1: 0.6063
#
# Epoch 00048: val_loss did not improve from 0.43090
# Epoch 49/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6432 - accuracy: 0.6283 - get_f1: 0.6308 - val_loss: 0.7763 - val_accuracy: 0.6172 - val_get_f1: 0.6085
#
# Epoch 00049: val_loss did not improve from 0.43090
# Epoch 50/50
# 1087/1087 [==============================] - 285s 262ms/step - loss: 0.6429 - accuracy: 0.6297 - get_f1: 0.6329 - val_loss: 0.7505 - val_accuracy: 0.6172 - val_get_f1: 0.6072
#
# Epoch 00050: val_loss did not improve from 0.43090
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.999999818536047e-12.
# Epoch 00050: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn
# 0      ../data/Photos/originals/2nzvcq.jpg        1       None
# 1      ../data/Photos/originals/10ela6.jpg        1       None
# 2  ../data/Photos/photoshops/cu71kx2_0.png        0       None
# 3  ../data/Photos/photoshops/dpf4ppy_0.jpg        0       None
# 4  ../data/Photos/photoshops/cikt3kh_0.jpg        0       None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4352 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)
# Out:
# 272/272 [==============================] - 57s 209ms/step

# %%
# Zamiana z 0-1 hot encodera na jedno wyjście
stats_df['predict_fn'] = list(map(lambda x: 1 if x > 0.5 else 0,predict_fn))

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn
# 0      ../data/Photos/originals/2nzvcq.jpg        1           1
# 1      ../data/Photos/originals/10ela6.jpg        1           1
# 2  ../data/Photos/photoshops/cu71kx2_0.png        0           1
# 3  ../data/Photos/photoshops/dpf4ppy_0.jpg        0           0
# 4  ../data/Photos/photoshops/cikt3kh_0.jpg        0           0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1331  845]
#  [ 820 1356]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 272/272 [==============================] - 56s 206ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.751
# Test accuracy: 0.617
# Test F1: 0.607

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6174172794117647
# Precision: 0.6174327801212881
# Recall: 0.6174172794117647
# F-score: 0.6174046541053648
