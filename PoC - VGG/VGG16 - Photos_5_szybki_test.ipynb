# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4535459946485311058
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 82775045854568224
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla VGG

IMAGE_WIDTH=224
IMAGE_HEIGHT=224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
df.shape
# Out:
# (21758, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
X.head()
# Out:
#                                   filename
# 0      ../data/Photos/originals/7ak2w6.jpg
# 1      ../data/Photos/originals/27lsoy.jpg
# 2      ../data/Photos/originals/7g0q9a.jpg
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg
# 4      ../data/Photos/originals/4ioqrn.jpg

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
from keras import optimizers

batch_size = 16
activation = 'relu'
loss_type = 'binary_crossentropy'
optimizer = optimizers.RMSprop(lr=2e-5)
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
'''

from keras.applications.vgg16 import preprocess_input

data_gen = ImageDataGenerator(
#     preprocessing_function=preprocess_input
    rescale=1./255,
#     zoom_range=[0, 0.2],
    horizontal_flip=True,
    vertical_flip=True
)

data_test_gen = ImageDataGenerator(
    rescale=1./255
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17406 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_test_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4352 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50
from keras.applications import VGG16

pre_trained_model_fn = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))

for layer in pre_trained_model_fn.layers[:5]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[5:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Flatten())
model_fn.add(Dropout(dropout))
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dense(1, activation='sigmoid'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6422784
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 21,025,153
# Non-trainable params: 112,576
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = 50,
    steps_per_epoch = 100,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P.h5')
# Out:
# Epoch 1/50
# 100/100 [==============================] - 45s 450ms/step - loss: 0.7245 - accuracy: 0.5200 - get_f1: 0.4904 - val_loss: 0.7591 - val_accuracy: 0.4888 - val_get_f1: 0.6470
#
# Epoch 00001: val_loss improved from inf to 0.75913, saving model to best.h5
# Epoch 2/50
# 100/100 [==============================] - 42s 416ms/step - loss: 0.6909 - accuracy: 0.5519 - get_f1: 0.5417 - val_loss: 0.6546 - val_accuracy: 0.5312 - val_get_f1: 0.1040
#
# Epoch 00002: val_loss improved from 0.75913 to 0.65460, saving model to best.h5
# Epoch 3/50
# 100/100 [==============================] - 44s 443ms/step - loss: 0.6850 - accuracy: 0.5657 - get_f1: 0.5549 - val_loss: 0.7388 - val_accuracy: 0.5500 - val_get_f1: 0.6886
#
# Epoch 00003: val_loss did not improve from 0.65460
# Epoch 4/50
# 100/100 [==============================] - 42s 422ms/step - loss: 0.6899 - accuracy: 0.5587 - get_f1: 0.5242 - val_loss: 0.7410 - val_accuracy: 0.5525 - val_get_f1: 0.3410
#
# Epoch 00004: val_loss did not improve from 0.65460
# Epoch 5/50
# 100/100 [==============================] - 42s 423ms/step - loss: 0.6787 - accuracy: 0.5625 - get_f1: 0.4446 - val_loss: 0.7318 - val_accuracy: 0.5663 - val_get_f1: 0.3588
#
# Epoch 00005: val_loss did not improve from 0.65460
# Epoch 6/50
# 100/100 [==============================] - 40s 398ms/step - loss: 0.6786 - accuracy: 0.5587 - get_f1: 0.5059 - val_loss: 0.6775 - val_accuracy: 0.5512 - val_get_f1: 0.2719
#
# Epoch 00006: val_loss did not improve from 0.65460
# Epoch 7/50
# 100/100 [==============================] - 38s 377ms/step - loss: 0.6850 - accuracy: 0.5775 - get_f1: 0.5687 - val_loss: 0.5652 - val_accuracy: 0.5825 - val_get_f1: 0.4549
#
# Epoch 00007: val_loss improved from 0.65460 to 0.56520, saving model to best.h5
# Epoch 8/50
# 100/100 [==============================] - 40s 397ms/step - loss: 0.6683 - accuracy: 0.5769 - get_f1: 0.5233 - val_loss: 0.6311 - val_accuracy: 0.6062 - val_get_f1: 0.6301
#
# Epoch 00008: val_loss did not improve from 0.56520
# Epoch 9/50
# 100/100 [==============================] - 38s 379ms/step - loss: 0.6746 - accuracy: 0.5625 - get_f1: 0.5358 - val_loss: 0.8502 - val_accuracy: 0.5763 - val_get_f1: 0.5209
#
# Epoch 00009: val_loss did not improve from 0.56520
# Epoch 10/50
# 100/100 [==============================] - 39s 391ms/step - loss: 0.6693 - accuracy: 0.5850 - get_f1: 0.5767 - val_loss: 0.9705 - val_accuracy: 0.5113 - val_get_f1: 0.0811
#
# Epoch 00010: val_loss did not improve from 0.56520
# Epoch 11/50
# 100/100 [==============================] - 39s 388ms/step - loss: 0.6764 - accuracy: 0.5962 - get_f1: 0.6007 - val_loss: 0.6710 - val_accuracy: 0.5650 - val_get_f1: 0.5586
#
# Epoch 00011: val_loss did not improve from 0.56520
# Epoch 12/50
# 100/100 [==============================] - 29s 286ms/step - loss: 0.6792 - accuracy: 0.5731 - get_f1: 0.5911 - val_loss: 0.6620 - val_accuracy: 0.6187 - val_get_f1: 0.6476
#
# Epoch 00012: val_loss did not improve from 0.56520
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# Epoch 13/50
# 100/100 [==============================] - 27s 267ms/step - loss: 0.6495 - accuracy: 0.6112 - get_f1: 0.6379 - val_loss: 0.7298 - val_accuracy: 0.6025 - val_get_f1: 0.6325
#
# Epoch 00013: val_loss did not improve from 0.56520
# Epoch 14/50
# 100/100 [==============================] - 27s 266ms/step - loss: 0.6583 - accuracy: 0.5987 - get_f1: 0.6131 - val_loss: 0.6510 - val_accuracy: 0.5900 - val_get_f1: 0.6272
#
# Epoch 00014: val_loss did not improve from 0.56520
# Epoch 15/50
# 100/100 [==============================] - 28s 281ms/step - loss: 0.6661 - accuracy: 0.6006 - get_f1: 0.6137 - val_loss: 0.6361 - val_accuracy: 0.6112 - val_get_f1: 0.6130
#
# Epoch 00015: val_loss did not improve from 0.56520
# Epoch 16/50
# 100/100 [==============================] - 27s 272ms/step - loss: 0.6395 - accuracy: 0.6200 - get_f1: 0.6123 - val_loss: 0.8846 - val_accuracy: 0.6300 - val_get_f1: 0.6710
#
# Epoch 00016: val_loss did not improve from 0.56520
# Epoch 17/50
# 100/100 [==============================] - 28s 276ms/step - loss: 0.6505 - accuracy: 0.6087 - get_f1: 0.6002 - val_loss: 0.6094 - val_accuracy: 0.6175 - val_get_f1: 0.6109
#
# Epoch 00017: val_loss did not improve from 0.56520
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.9999999949504855e-07.
# Epoch 18/50
# 100/100 [==============================] - 26s 264ms/step - loss: 0.6569 - accuracy: 0.6175 - get_f1: 0.6264 - val_loss: 0.6713 - val_accuracy: 0.6062 - val_get_f1: 0.6226
#
# Epoch 00018: val_loss did not improve from 0.56520
# Epoch 19/50
# 100/100 [==============================] - 28s 276ms/step - loss: 0.6367 - accuracy: 0.6294 - get_f1: 0.6408 - val_loss: 0.6271 - val_accuracy: 0.6288 - val_get_f1: 0.6290
#
# Epoch 00019: val_loss did not improve from 0.56520
# Epoch 20/50
# 100/100 [==============================] - 29s 293ms/step - loss: 0.6653 - accuracy: 0.5995 - get_f1: 0.5875 - val_loss: 0.6459 - val_accuracy: 0.5763 - val_get_f1: 0.5656
#
# Epoch 00020: val_loss did not improve from 0.56520
# Epoch 21/50
# 100/100 [==============================] - 27s 271ms/step - loss: 0.6551 - accuracy: 0.5981 - get_f1: 0.5800 - val_loss: 0.4799 - val_accuracy: 0.6162 - val_get_f1: 0.5924
#
# Epoch 00021: val_loss improved from 0.56520 to 0.47985, saving model to best.h5
# Epoch 22/50
# 100/100 [==============================] - 28s 279ms/step - loss: 0.6599 - accuracy: 0.6169 - get_f1: 0.6132 - val_loss: 0.6578 - val_accuracy: 0.6125 - val_get_f1: 0.5808
#
# Epoch 00022: val_loss did not improve from 0.47985
# Epoch 23/50
# 100/100 [==============================] - 28s 284ms/step - loss: 0.6491 - accuracy: 0.6219 - get_f1: 0.6185 - val_loss: 0.7003 - val_accuracy: 0.5863 - val_get_f1: 0.5558
#
# Epoch 00023: val_loss did not improve from 0.47985
# Epoch 24/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.6406 - accuracy: 0.6369 - get_f1: 0.6408 - val_loss: 0.6321 - val_accuracy: 0.5962 - val_get_f1: 0.5837
#
# Epoch 00024: val_loss did not improve from 0.47985
# Epoch 25/50
# 100/100 [==============================] - 27s 270ms/step - loss: 0.6475 - accuracy: 0.6294 - get_f1: 0.6166 - val_loss: 0.6368 - val_accuracy: 0.6025 - val_get_f1: 0.5921
#
# Epoch 00025: val_loss did not improve from 0.47985
# Epoch 26/50
# 100/100 [==============================] - 27s 271ms/step - loss: 0.6627 - accuracy: 0.5814 - get_f1: 0.5565 - val_loss: 0.6647 - val_accuracy: 0.6363 - val_get_f1: 0.6325
#
# Epoch 00026: val_loss did not improve from 0.47985
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.000000023372195e-08.
# Epoch 27/50
# 100/100 [==============================] - 27s 271ms/step - loss: 0.6418 - accuracy: 0.6081 - get_f1: 0.6045 - val_loss: 0.7048 - val_accuracy: 0.6162 - val_get_f1: 0.6111
#
# Epoch 00027: val_loss did not improve from 0.47985
# Epoch 28/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.6487 - accuracy: 0.6244 - get_f1: 0.6110 - val_loss: 0.5851 - val_accuracy: 0.6162 - val_get_f1: 0.6116
#
# Epoch 00028: val_loss did not improve from 0.47985
# Epoch 29/50
# 100/100 [==============================] - 27s 271ms/step - loss: 0.6413 - accuracy: 0.6319 - get_f1: 0.6316 - val_loss: 0.5682 - val_accuracy: 0.6037 - val_get_f1: 0.5941
#
# Epoch 00029: val_loss did not improve from 0.47985
# Epoch 30/50
# 100/100 [==============================] - 27s 267ms/step - loss: 0.6367 - accuracy: 0.6313 - get_f1: 0.6419 - val_loss: 0.7419 - val_accuracy: 0.5962 - val_get_f1: 0.5726
#
# Epoch 00030: val_loss did not improve from 0.47985
# Epoch 31/50
# 100/100 [==============================] - 28s 278ms/step - loss: 0.6401 - accuracy: 0.6206 - get_f1: 0.6149 - val_loss: 0.6080 - val_accuracy: 0.5962 - val_get_f1: 0.5837
#
# Epoch 00031: val_loss did not improve from 0.47985
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.9999999878450583e-09.
# Epoch 32/50
# 100/100 [==============================] - 27s 275ms/step - loss: 0.6574 - accuracy: 0.6106 - get_f1: 0.6067 - val_loss: 0.6607 - val_accuracy: 0.6237 - val_get_f1: 0.6053
#
# Epoch 00032: val_loss did not improve from 0.47985
# Epoch 33/50
# 100/100 [==============================] - 28s 278ms/step - loss: 0.6402 - accuracy: 0.6181 - get_f1: 0.6067 - val_loss: 0.8341 - val_accuracy: 0.6087 - val_get_f1: 0.6177
#
# Epoch 00033: val_loss did not improve from 0.47985
# Epoch 34/50
# 100/100 [==============================] - 27s 273ms/step - loss: 0.6429 - accuracy: 0.6256 - get_f1: 0.6162 - val_loss: 0.5353 - val_accuracy: 0.6175 - val_get_f1: 0.6323
#
# Epoch 00034: val_loss did not improve from 0.47985
# Epoch 35/50
# 100/100 [==============================] - 29s 290ms/step - loss: 0.6457 - accuracy: 0.6106 - get_f1: 0.6123 - val_loss: 0.5767 - val_accuracy: 0.6075 - val_get_f1: 0.6000
#
# Epoch 00035: val_loss did not improve from 0.47985
# Epoch 36/50
# 100/100 [==============================] - 28s 280ms/step - loss: 0.6618 - accuracy: 0.6100 - get_f1: 0.6039 - val_loss: 0.6852 - val_accuracy: 0.5962 - val_get_f1: 0.5623
#
# Epoch 00036: val_loss did not improve from 0.47985
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.999999943436137e-10.
# Epoch 00036: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn
# 0  ../data/Photos/photoshops/ce3cziy_0.png        0       None
# 1  ../data/Photos/photoshops/dg19jon_0.jpg        0       None
# 2  ../data/Photos/photoshops/c5vyb2f_0.jpg        0       None
# 3      ../data/Photos/originals/1ghb5u.jpg        1       None
# 4  ../data/Photos/photoshops/cakqhuh_0.jpg        0       None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4352 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)
# Out:
# 272/272 [==============================] - 55s 203ms/step

# %%
# Zamiana z 0-1 hot encodera na jedno wyjście
stats_df['predict_fn'] = list(map(lambda x: 1 if x > 0.5 else 0,predict_fn))

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn
# 0  ../data/Photos/photoshops/ce3cziy_0.png        0           0
# 1  ../data/Photos/photoshops/dg19jon_0.jpg        0           1
# 2  ../data/Photos/photoshops/c5vyb2f_0.jpg        0           1
# 3      ../data/Photos/originals/1ghb5u.jpg        1           1
# 4  ../data/Photos/photoshops/cakqhuh_0.jpg        0           0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1311  865]
#  [ 831 1345]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 272/272 [==============================] - 56s 205ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.742
# Test accuracy: 0.607
# Test F1: 0.594

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6102941176470589
# Precision: 0.6103210514975221
# Recall: 0.6102941176470589
# F-score: 0.6102703304357817
