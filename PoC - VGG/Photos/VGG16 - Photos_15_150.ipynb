# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16323337822844487257
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16958203391342444331
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla VGG

IMAGE_WIDTH=150
IMAGE_HEIGHT=150
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
df.shape
# Out:
# (21758, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
X.head()
# Out:
#                                   filename
# 0      ../data/Photos/originals/7ak2w6.jpg
# 1      ../data/Photos/originals/27lsoy.jpg
# 2      ../data/Photos/originals/7g0q9a.jpg
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg
# 4      ../data/Photos/originals/4ioqrn.jpg

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
from keras import optimizers

batch_size = 16
activation = 'relu'
loss_type = 'binary_crossentropy'
optimizer = optimizers.RMSprop(lr=2e-5)
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
'''

from keras.applications.vgg16 import preprocess_input

data_gen = ImageDataGenerator(
#     preprocessing_function=preprocess_input
    rescale=1./255,
#     zoom_range=[0, 0.2],
    horizontal_flip=True,
    vertical_flip=True
)

data_test_gen = ImageDataGenerator(
    rescale=1./255
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17406 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_test_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4352 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50
from keras.applications import VGG16

pre_trained_model_fn = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))

for layer in pre_trained_model_fn.layers[:15]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[15:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Flatten())
model_fn.add(Dropout(dropout))
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dense(1, activation='sigmoid'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P.h5')
# Out:
# Epoch 1/50
# 1087/1087 [==============================] - 458s 422ms/step - loss: 0.6725 - accuracy: 0.5806 - get_f1: 0.5641 - val_loss: 0.6398 - val_accuracy: 0.6094 - val_get_f1: 0.5791
#
# Epoch 00001: val_loss improved from inf to 0.63980, saving model to best.h5
# Epoch 2/50
# 1087/1087 [==============================] - 281s 259ms/step - loss: 0.6516 - accuracy: 0.6085 - get_f1: 0.5979 - val_loss: 0.6380 - val_accuracy: 0.5990 - val_get_f1: 0.5549
#
# Epoch 00002: val_loss improved from 0.63980 to 0.63800, saving model to best.h5
# Epoch 3/50
# 1087/1087 [==============================] - 279s 257ms/step - loss: 0.6444 - accuracy: 0.6190 - get_f1: 0.6122 - val_loss: 0.6802 - val_accuracy: 0.5882 - val_get_f1: 0.4951
#
# Epoch 00003: val_loss did not improve from 0.63800
# Epoch 4/50
# 1087/1087 [==============================] - 282s 259ms/step - loss: 0.6404 - accuracy: 0.6288 - get_f1: 0.6237 - val_loss: 0.6146 - val_accuracy: 0.6131 - val_get_f1: 0.6250
#
# Epoch 00004: val_loss improved from 0.63800 to 0.61460, saving model to best.h5
# Epoch 5/50
# 1087/1087 [==============================] - 280s 258ms/step - loss: 0.6374 - accuracy: 0.6297 - get_f1: 0.6183 - val_loss: 0.8477 - val_accuracy: 0.6133 - val_get_f1: 0.6278
#
# Epoch 00005: val_loss did not improve from 0.61460
# Epoch 6/50
# 1087/1087 [==============================] - 284s 261ms/step - loss: 0.6369 - accuracy: 0.6335 - get_f1: 0.6268 - val_loss: 0.6670 - val_accuracy: 0.6062 - val_get_f1: 0.6188
#
# Epoch 00006: val_loss did not improve from 0.61460
# Epoch 7/50
# 1087/1087 [==============================] - 281s 259ms/step - loss: 0.6354 - accuracy: 0.6347 - get_f1: 0.6309 - val_loss: 0.7814 - val_accuracy: 0.6094 - val_get_f1: 0.5803
#
# Epoch 00007: val_loss did not improve from 0.61460
# Epoch 8/50
# 1087/1087 [==============================] - 280s 257ms/step - loss: 0.6388 - accuracy: 0.6308 - get_f1: 0.6239 - val_loss: 0.5895 - val_accuracy: 0.6057 - val_get_f1: 0.6422
#
# Epoch 00008: val_loss improved from 0.61460 to 0.58948, saving model to best.h5
# Epoch 9/50
# 1087/1087 [==============================] - 282s 259ms/step - loss: 0.6459 - accuracy: 0.6255 - get_f1: 0.6231 - val_loss: 0.5729 - val_accuracy: 0.6124 - val_get_f1: 0.5984
#
# Epoch 00009: val_loss improved from 0.58948 to 0.57286, saving model to best.h5
# Epoch 10/50
# 1087/1087 [==============================] - 280s 257ms/step - loss: 0.6417 - accuracy: 0.6330 - get_f1: 0.6244 - val_loss: 0.9953 - val_accuracy: 0.6096 - val_get_f1: 0.6703
#
# Epoch 00010: val_loss did not improve from 0.57286
# Epoch 11/50
# 1087/1087 [==============================] - 283s 260ms/step - loss: 0.6537 - accuracy: 0.6319 - get_f1: 0.6206 - val_loss: 0.7166 - val_accuracy: 0.5908 - val_get_f1: 0.4853
#
# Epoch 00011: val_loss did not improve from 0.57286
# Epoch 12/50
# 1087/1087 [==============================] - 283s 261ms/step - loss: 0.6490 - accuracy: 0.6248 - get_f1: 0.6165 - val_loss: 0.6884 - val_accuracy: 0.6057 - val_get_f1: 0.5537
#
# Epoch 00012: val_loss did not improve from 0.57286
# Epoch 13/50
# 1087/1087 [==============================] - 282s 260ms/step - loss: 0.6504 - accuracy: 0.6240 - get_f1: 0.6133 - val_loss: 0.7323 - val_accuracy: 0.6004 - val_get_f1: 0.6494
#
# Epoch 00013: val_loss did not improve from 0.57286
# Epoch 14/50
# 1087/1087 [==============================] - 280s 258ms/step - loss: 0.6602 - accuracy: 0.6260 - get_f1: 0.6174 - val_loss: 0.7677 - val_accuracy: 0.5924 - val_get_f1: 0.4763
#
# Epoch 00014: val_loss did not improve from 0.57286
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# Epoch 15/50
# 1087/1087 [==============================] - 282s 259ms/step - loss: 0.6321 - accuracy: 0.6452 - get_f1: 0.6369 - val_loss: 1.2421 - val_accuracy: 0.6114 - val_get_f1: 0.5974
#
# Epoch 00015: val_loss did not improve from 0.57286
# Epoch 16/50
# 1087/1087 [==============================] - 283s 260ms/step - loss: 0.6321 - accuracy: 0.6481 - get_f1: 0.6456 - val_loss: 0.8629 - val_accuracy: 0.6073 - val_get_f1: 0.5694
#
# Epoch 00016: val_loss did not improve from 0.57286
# Epoch 17/50
# 1087/1087 [==============================] - 329s 302ms/step - loss: 0.6277 - accuracy: 0.6469 - get_f1: 0.6377 - val_loss: 0.6401 - val_accuracy: 0.6027 - val_get_f1: 0.5547
#
# Epoch 00017: val_loss did not improve from 0.57286
# Epoch 18/50
# 1087/1087 [==============================] - 286s 263ms/step - loss: 0.6328 - accuracy: 0.6466 - get_f1: 0.6418 - val_loss: 0.5956 - val_accuracy: 0.6039 - val_get_f1: 0.5488
#
# Epoch 00018: val_loss did not improve from 0.57286
# Epoch 19/50
# 1087/1087 [==============================] - 281s 258ms/step - loss: 0.6277 - accuracy: 0.6490 - get_f1: 0.6436 - val_loss: 4.7588 - val_accuracy: 0.6082 - val_get_f1: 0.5715
#
# Epoch 00019: val_loss did not improve from 0.57286
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.9999999949504855e-07.
# Epoch 20/50
# 1087/1087 [==============================] - 279s 257ms/step - loss: 0.6206 - accuracy: 0.6527 - get_f1: 0.6485 - val_loss: 0.6633 - val_accuracy: 0.6052 - val_get_f1: 0.5589
#
# Epoch 00020: val_loss did not improve from 0.57286
# Epoch 21/50
# 1087/1087 [==============================] - 372s 342ms/step - loss: 0.6218 - accuracy: 0.6503 - get_f1: 0.6419 - val_loss: 0.9024 - val_accuracy: 0.6091 - val_get_f1: 0.5779
#
# Epoch 00021: val_loss did not improve from 0.57286
# Epoch 22/50
# 1087/1087 [==============================] - 351s 323ms/step - loss: 0.6302 - accuracy: 0.6553 - get_f1: 0.6521 - val_loss: 0.5791 - val_accuracy: 0.6071 - val_get_f1: 0.5718
#
# Epoch 00022: val_loss did not improve from 0.57286
# Epoch 23/50
# 1087/1087 [==============================] - 354s 326ms/step - loss: 0.6260 - accuracy: 0.6523 - get_f1: 0.6473 - val_loss: 0.6746 - val_accuracy: 0.6071 - val_get_f1: 0.5723
#
# Epoch 00023: val_loss did not improve from 0.57286
# Epoch 24/50
# 1087/1087 [==============================] - 339s 312ms/step - loss: 0.6237 - accuracy: 0.6532 - get_f1: 0.6509 - val_loss: 0.6997 - val_accuracy: 0.6066 - val_get_f1: 0.5687
#
# Epoch 00024: val_loss did not improve from 0.57286
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.000000023372195e-08.
# Epoch 00024: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn
# 0  ../data/Photos/photoshops/clw0equ_0.jpg        0       None
# 1      ../data/Photos/originals/3ipraf.jpg        1       None
# 2      ../data/Photos/originals/23avmd.jpg        1       None
# 3  ../data/Photos/photoshops/cbdaide_0.jpg        0       None
# 4      ../data/Photos/originals/2dd5m0.png        1       None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4352 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)
# Out:
# 272/272 [==============================] - 62s 227ms/step

# %%
# Zamiana z 0-1 hot encodera na jedno wyjście
stats_df['predict_fn'] = list(map(lambda x: 1 if x > 0.5 else 0,predict_fn))

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn
# 0  ../data/Photos/photoshops/clw0equ_0.jpg        0           0
# 1      ../data/Photos/originals/3ipraf.jpg        1           1
# 2      ../data/Photos/originals/23avmd.jpg        1           0
# 3  ../data/Photos/photoshops/cbdaide_0.jpg        0           1
# 4      ../data/Photos/originals/2dd5m0.png        1           0

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1326  850]
#  [ 828 1348]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 272/272 [==============================] - 60s 222ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 0.447
# Test accuracy: 0.612
# Test F1: 0.597

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6144301470588235
# Precision: 0.6144418450807395
# Recall: 0.6144301470588235
# F-score: 0.6144202937576758
