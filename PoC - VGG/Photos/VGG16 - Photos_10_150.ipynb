# %% [markdown]
# # Sprawdzanie środowiska

# %%
from platform import python_version

print(python_version())

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 3.7.4
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16658926960170292628
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6661821563
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 17146489963946881770
# physical_device_desc: "device: 0, name: GeForce GTX 1070 Ti, pci bus id: 0000:1f:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# # Przygotowanie odpowiednich danych

# %%
# Jeśli zajdzie potrzeba
# from google.colab import drive

# drive.mount('/content/drive')

# %%
'''
Dla PoC wykonuje obliczenia dla:
 * '../data/DogsCats'
Folder docelowy:
 * '../data/Photos'
'''

dir_path = '../data/Photos'
A_folder = 'originals'
B_folder = 'photoshops'

# %% [markdown]
# # Załadowanie danych

# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import math
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import random
import os

# fix random bo tak ( ͡° ͜ʖ ͡°)
odp = 42
numpy.random.seed(odp)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Stałe

# %%
# Wilkości odpowiednie dla VGG

IMAGE_WIDTH=150
IMAGE_HEIGHT=150
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Przygotowanie Danych

# %%
'''
Opis danych:
1 - klasa 1 -> Originals
0 - klasa 2 -> Photoshops
''' 

A_folder_list = os.listdir(dir_path + '/' + A_folder)
B_folder_list = os.listdir(dir_path + '/' + B_folder)

filenames = []
categories = []

for filename in A_folder_list:
    categories.append(1)
    filenames.append(dir_path + '/' + A_folder + '/' + filename)

for filename in B_folder_list:
    categories.append(0)
    filenames.append(dir_path + '/' + B_folder + '/' + filename)


df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
# Mieszamy!
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
df.shape
# Out:
# (21758, 2)

# %%
df['category'].value_counts().plot.bar()

# %%
sample = random.choice(df['filename'])
image = load_img(sample)
plt.imshow(image)

# %% [markdown]
# # Obróbka danych

# %%
 '''
Podział danych z całego df na X i y:

X - wszystko oprócz category
y - category
'''

X, y = df.iloc[:, 0:-1], df.iloc[:, -1]

# %%
df.head()
# Out:
#                                   filename  category
# 0      ../data/Photos/originals/7ak2w6.jpg         1
# 1      ../data/Photos/originals/27lsoy.jpg         1
# 2      ../data/Photos/originals/7g0q9a.jpg         1
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg         0
# 4      ../data/Photos/originals/4ioqrn.jpg         1

# %%
X.head()
# Out:
#                                   filename
# 0      ../data/Photos/originals/7ak2w6.jpg
# 1      ../data/Photos/originals/27lsoy.jpg
# 2      ../data/Photos/originals/7g0q9a.jpg
# 3  ../data/Photos/photoshops/da1jeqf_0.jpg
# 4      ../data/Photos/originals/4ioqrn.jpg

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: category, dtype: int64

# %%
# 20% danych do testów
kf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = odp)
result = next(kf.split(X, y))

'''
Podział danych z całego df na podstawie splitu

train - 80% danych
test  - 20% danych
'''
train = df.iloc[result[0]]
test =  df.iloc[result[1]]

# Reset indeksów
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
train['category'].value_counts().plot.bar()

# %%
test['category'].value_counts().plot.bar()

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %%
# Upewnienie się że dane w train[filename] i test[filename] są stringiem - lepsze dla generatorów

train['filename'] = train['filename'].astype(str) 
test['filename'] = test['filename'].astype(str)

# Upewnienie się że dane w train[category] i test[category] są stringiem - lepsze dla generatorów

train['category'] = train['category'].astype(str) 
test['category'] = test['category'].astype(str)

# %%
print(f'Kształt danych:')
print(f'\t df: {df.shape}')

print(f'\t train: {train.shape}')
print(f'\t test: {test.shape}')
# Out:
# Kształt danych:
# 	 df: (21758, 2)
# 	 train: (17406, 2)
# 	 test: (4352, 2)

# %% [markdown]
# # Funkcję liczące statystyki

# %%
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score, roc_auc_score

# %%
def countStats(_y_true, _y_pred):
    accuracy = accuracy_score(_y_true, _y_pred, normalize=True)
    precision = precision_score(_y_true, _y_pred, average='weighted')
    recall = recall_score(_y_true, _y_pred, average='weighted')
    fscore = f1_score(_y_true, _y_pred, average='weighted')
    
    return accuracy, precision, recall, fscore

# %%
'''
Źrodło:
https://medium.com/@aakashgoel12/how-to-add-user-defined-function-get-f1-score-in-keras-metrics-3013f979ce0d
'''

def get_f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    
    return f1_val

# %%
from mlxtend.plotting import plot_confusion_matrix

def plot_cm(cm, classes):
    plot_confusion_matrix(conf_mat=cm,
                          colorbar=True, 
                          show_absolute=True,
                          show_normed=True,
                          class_names=classes)

# %%
'''
cb_early_stopper - skończenie uczenia kiedy val_loss nie będzie się poprawiać przez 10 epok
cb_checkpointer - zapis modelu do pliku 'best.h5' modeli o najlepszym(najmniejszym) val_loss
cb_learning_rate_reduction - zmniejszenie LR jeśli val_loss nie będzie się poprawiać przez 5 epok
'''

EARLY_STOP_PATIENCE = 15
LEARNING_RATE_PATIENCE = 5

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE, verbose=1)
cb_checkpointer = ModelCheckpoint(filepath = 'best.h5', monitor = 'val_loss', save_best_only = True, verbose=1)
cb_learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=LEARNING_RATE_PATIENCE, verbose=1)

# %% [markdown]
# # Dobór parametrów

# %%
from keras import optimizers

batch_size = 16
activation = 'relu'
loss_type = 'binary_crossentropy'
optimizer = optimizers.RMSprop(lr=2e-5)
dropout = 0.25
epochs = 50

# %% [markdown]
# # Generatory

# %%
'''
Generator dla danych trenningowych
'''

from keras.applications.vgg16 import preprocess_input

data_gen = ImageDataGenerator(
#     preprocessing_function=preprocess_input
    rescale=1./255,
#     zoom_range=[0, 0.2],
    horizontal_flip=True,
    vertical_flip=True
)

data_test_gen = ImageDataGenerator(
    rescale=1./255
)

train_generator = data_gen.flow_from_dataframe(
    dataframe = train,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 17406 validated image filenames belonging to 2 classes.

# %%
'''
Generator dla danych testowych
 * reskalowanie
'''

test_generator = data_test_gen.flow_from_dataframe( 
    dataframe = test,
    x_col = 'filename',
    y_col = 'category',
    class_mode='binary',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 4352 validated image filenames belonging to 2 classes.

# %%
example_df = train.sample(n=1).reset_index(drop=True)

example_generator = data_gen.flow_from_dataframe(
    dataframe = example_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode='categorical',
    target_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Fine-Tuning

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.applications.resnet import ResNet50
from keras.applications import VGG16

pre_trained_model_fn = VGG16(weights='imagenet', include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))

for layer in pre_trained_model_fn.layers[:10]:
    layer.trainable = False

for layer in pre_trained_model_fn.layers[10:]:
    layer.trainable = True

model_fn = Sequential()

model_fn.add(pre_trained_model_fn)
model_fn.add(Flatten())
model_fn.add(Dropout(dropout))
model_fn.add(Dense(256, activation=activation))
model_fn.add(Dense(1, activation='sigmoid'))

model_fn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 15,076,865
# Non-trainable params: 1,735,488
# _________________________________________________________________

# %% [markdown]
# # Fit

# %%
model_fn.compile(loss=loss_type, optimizer=optimizer, metrics=['accuracy', get_f1])

history_fn = model_fn.fit_generator(
    train_generator, 
    epochs = epochs,
    validation_data = test_generator,
    validation_steps = test.shape[0]//batch_size,
    steps_per_epoch = train.shape[0]//batch_size,
    callbacks = [cb_checkpointer, cb_early_stopper, cb_learning_rate_reduction]
)

# Wczytanie najlepszego
model_fn.load_weights('best.h5')

# Zapis
model_fn.save('the_best_fn_P.h5')
# Out:
# Epoch 1/50
# 1087/1087 [==============================] - 428s 394ms/step - loss: 0.6758 - accuracy: 0.5783 - get_f1: 0.5544 - val_loss: 0.7014 - val_accuracy: 0.6135 - val_get_f1: 0.6388
#
# Epoch 00001: val_loss improved from inf to 0.70140, saving model to best.h5
# Epoch 2/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6581 - accuracy: 0.6015 - get_f1: 0.5933 - val_loss: 0.6175 - val_accuracy: 0.5790 - val_get_f1: 0.4407
#
# Epoch 00002: val_loss improved from 0.70140 to 0.61746, saving model to best.h5
# Epoch 3/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6561 - accuracy: 0.6091 - get_f1: 0.6040 - val_loss: 0.6412 - val_accuracy: 0.6103 - val_get_f1: 0.6036
#
# Epoch 00003: val_loss did not improve from 0.61746
# Epoch 4/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6616 - accuracy: 0.6114 - get_f1: 0.6033 - val_loss: 0.5695 - val_accuracy: 0.5949 - val_get_f1: 0.5250
#
# Epoch 00004: val_loss improved from 0.61746 to 0.56948, saving model to best.h5
# Epoch 5/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6694 - accuracy: 0.6054 - get_f1: 0.5864 - val_loss: 0.7103 - val_accuracy: 0.6025 - val_get_f1: 0.5744
#
# Epoch 00005: val_loss did not improve from 0.56948
# Epoch 6/50
# 1087/1087 [==============================] - 276s 253ms/step - loss: 0.6726 - accuracy: 0.6012 - get_f1: 0.5775 - val_loss: 0.6454 - val_accuracy: 0.5191 - val_get_f1: 0.1063
#
# Epoch 00006: val_loss did not improve from 0.56948
# Epoch 7/50
# 1087/1087 [==============================] - 278s 256ms/step - loss: 0.6762 - accuracy: 0.5970 - get_f1: 0.5883 - val_loss: 0.6865 - val_accuracy: 0.6013 - val_get_f1: 0.5668
#
# Epoch 00007: val_loss did not improve from 0.56948
# Epoch 8/50
# 1087/1087 [==============================] - 277s 254ms/step - loss: 0.6835 - accuracy: 0.5939 - get_f1: 0.5965 - val_loss: 0.6116 - val_accuracy: 0.6045 - val_get_f1: 0.6502
#
# Epoch 00008: val_loss did not improve from 0.56948
# Epoch 9/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6765 - accuracy: 0.5911 - get_f1: 0.5745 - val_loss: 0.6724 - val_accuracy: 0.5974 - val_get_f1: 0.6196
#
# Epoch 00009: val_loss did not improve from 0.56948
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# Epoch 10/50
# 1087/1087 [==============================] - 278s 256ms/step - loss: 0.6536 - accuracy: 0.6133 - get_f1: 0.5982 - val_loss: 0.8253 - val_accuracy: 0.6126 - val_get_f1: 0.6217
#
# Epoch 00010: val_loss did not improve from 0.56948
# Epoch 11/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6530 - accuracy: 0.6128 - get_f1: 0.6179 - val_loss: 1.0970 - val_accuracy: 0.6117 - val_get_f1: 0.6153
#
# Epoch 00011: val_loss did not improve from 0.56948
# Epoch 12/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6526 - accuracy: 0.6142 - get_f1: 0.6114 - val_loss: 0.5874 - val_accuracy: 0.6128 - val_get_f1: 0.6339
#
# Epoch 00012: val_loss did not improve from 0.56948
# Epoch 13/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6475 - accuracy: 0.6183 - get_f1: 0.6180 - val_loss: 0.6021 - val_accuracy: 0.6108 - val_get_f1: 0.6243
#
# Epoch 00013: val_loss did not improve from 0.56948
# Epoch 14/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6588 - accuracy: 0.6223 - get_f1: 0.6251 - val_loss: 1.1379 - val_accuracy: 0.6128 - val_get_f1: 0.6158
#
# Epoch 00014: val_loss did not improve from 0.56948
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.9999999949504855e-07.
# Epoch 15/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6534 - accuracy: 0.6228 - get_f1: 0.6207 - val_loss: 0.7106 - val_accuracy: 0.6131 - val_get_f1: 0.6330
#
# Epoch 00015: val_loss did not improve from 0.56948
# Epoch 16/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6516 - accuracy: 0.6233 - get_f1: 0.6209 - val_loss: 0.5613 - val_accuracy: 0.6121 - val_get_f1: 0.6086
#
# Epoch 00016: val_loss improved from 0.56948 to 0.56127, saving model to best.h5
# Epoch 17/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6475 - accuracy: 0.6227 - get_f1: 0.6229 - val_loss: 0.7611 - val_accuracy: 0.6121 - val_get_f1: 0.6131
#
# Epoch 00017: val_loss did not improve from 0.56127
# Epoch 18/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6494 - accuracy: 0.6216 - get_f1: 0.6243 - val_loss: 0.6471 - val_accuracy: 0.6142 - val_get_f1: 0.6264
#
# Epoch 00018: val_loss did not improve from 0.56127
# Epoch 19/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6465 - accuracy: 0.6238 - get_f1: 0.6286 - val_loss: 0.5630 - val_accuracy: 0.6112 - val_get_f1: 0.6076
#
# Epoch 00019: val_loss did not improve from 0.56127
# Epoch 20/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6528 - accuracy: 0.6242 - get_f1: 0.6233 - val_loss: 0.6210 - val_accuracy: 0.6103 - val_get_f1: 0.6040
#
# Epoch 00020: val_loss did not improve from 0.56127
# Epoch 21/50
# 1087/1087 [==============================] - 273s 251ms/step - loss: 0.6526 - accuracy: 0.6219 - get_f1: 0.6212 - val_loss: 0.8297 - val_accuracy: 0.6133 - val_get_f1: 0.6110
#
# Epoch 00021: val_loss did not improve from 0.56127
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.000000023372195e-08.
# Epoch 22/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6466 - accuracy: 0.6243 - get_f1: 0.6224 - val_loss: 0.5497 - val_accuracy: 0.6131 - val_get_f1: 0.6160
#
# Epoch 00022: val_loss improved from 0.56127 to 0.54968, saving model to best.h5
# Epoch 23/50
# 1087/1087 [==============================] - 277s 255ms/step - loss: 0.6455 - accuracy: 0.6217 - get_f1: 0.6236 - val_loss: 0.7108 - val_accuracy: 0.6137 - val_get_f1: 0.6159
#
# Epoch 00023: val_loss did not improve from 0.54968
# Epoch 24/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6481 - accuracy: 0.6233 - get_f1: 0.6281 - val_loss: 0.8056 - val_accuracy: 0.6133 - val_get_f1: 0.6170
#
# Epoch 00024: val_loss did not improve from 0.54968
# Epoch 25/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6495 - accuracy: 0.6237 - get_f1: 0.6257 - val_loss: 0.6197 - val_accuracy: 0.6128 - val_get_f1: 0.6159
#
# Epoch 00025: val_loss did not improve from 0.54968
# Epoch 26/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6458 - accuracy: 0.6247 - get_f1: 0.6285 - val_loss: 0.5751 - val_accuracy: 0.6149 - val_get_f1: 0.6148
#
# Epoch 00026: val_loss did not improve from 0.54968
# Epoch 27/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6459 - accuracy: 0.6242 - get_f1: 0.6266 - val_loss: 0.6056 - val_accuracy: 0.6149 - val_get_f1: 0.6137
#
# Epoch 00027: val_loss did not improve from 0.54968
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.9999999878450583e-09.
# Epoch 28/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6503 - accuracy: 0.6204 - get_f1: 0.6237 - val_loss: 0.7099 - val_accuracy: 0.6149 - val_get_f1: 0.6177
#
# Epoch 00028: val_loss did not improve from 0.54968
# Epoch 29/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6429 - accuracy: 0.6269 - get_f1: 0.6283 - val_loss: 0.5333 - val_accuracy: 0.6147 - val_get_f1: 0.6158
#
# Epoch 00029: val_loss improved from 0.54968 to 0.53328, saving model to best.h5
# Epoch 30/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6495 - accuracy: 0.6178 - get_f1: 0.6190 - val_loss: 0.6086 - val_accuracy: 0.6140 - val_get_f1: 0.6161
#
# Epoch 00030: val_loss did not improve from 0.53328
# Epoch 31/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6441 - accuracy: 0.6259 - get_f1: 0.6322 - val_loss: 0.7621 - val_accuracy: 0.6142 - val_get_f1: 0.6160
#
# Epoch 00031: val_loss did not improve from 0.53328
# Epoch 32/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6531 - accuracy: 0.6237 - get_f1: 0.6263 - val_loss: 0.6576 - val_accuracy: 0.6140 - val_get_f1: 0.6139
#
# Epoch 00032: val_loss did not improve from 0.53328
# Epoch 33/50
# 1087/1087 [==============================] - 274s 252ms/step - loss: 0.6454 - accuracy: 0.6232 - get_f1: 0.6275 - val_loss: 0.6089 - val_accuracy: 0.6149 - val_get_f1: 0.6133
#
# Epoch 00033: val_loss did not improve from 0.53328
# Epoch 34/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6505 - accuracy: 0.6212 - get_f1: 0.6229 - val_loss: 0.9024 - val_accuracy: 0.6144 - val_get_f1: 0.6191
#
# Epoch 00034: val_loss did not improve from 0.53328
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.999999943436137e-10.
# Epoch 35/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6565 - accuracy: 0.6231 - get_f1: 0.6260 - val_loss: 0.6297 - val_accuracy: 0.6144 - val_get_f1: 0.6135
#
# Epoch 00035: val_loss did not improve from 0.53328
# Epoch 36/50
# 1087/1087 [==============================] - 273s 251ms/step - loss: 0.6499 - accuracy: 0.6215 - get_f1: 0.6220 - val_loss: 0.8193 - val_accuracy: 0.6144 - val_get_f1: 0.6162
#
# Epoch 00036: val_loss did not improve from 0.53328
# Epoch 37/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6521 - accuracy: 0.6194 - get_f1: 0.6199 - val_loss: 0.6095 - val_accuracy: 0.6144 - val_get_f1: 0.6164
#
# Epoch 00037: val_loss did not improve from 0.53328
# Epoch 38/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6459 - accuracy: 0.6251 - get_f1: 0.6263 - val_loss: 0.5485 - val_accuracy: 0.6144 - val_get_f1: 0.6146
#
# Epoch 00038: val_loss did not improve from 0.53328
# Epoch 39/50
# 1087/1087 [==============================] - 273s 251ms/step - loss: 0.6540 - accuracy: 0.6241 - get_f1: 0.6252 - val_loss: 0.5856 - val_accuracy: 0.6144 - val_get_f1: 0.6168
#
# Epoch 00039: val_loss did not improve from 0.53328
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.999999887924986e-11.
# Epoch 40/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6478 - accuracy: 0.6239 - get_f1: 0.6250 - val_loss: 0.5892 - val_accuracy: 0.6144 - val_get_f1: 0.6156
#
# Epoch 00040: val_loss did not improve from 0.53328
# Epoch 41/50
# 1087/1087 [==============================] - 275s 253ms/step - loss: 0.6511 - accuracy: 0.6210 - get_f1: 0.6222 - val_loss: 0.6081 - val_accuracy: 0.6144 - val_get_f1: 0.6194
#
# Epoch 00041: val_loss did not improve from 0.53328
# Epoch 42/50
# 1087/1087 [==============================] - 273s 251ms/step - loss: 0.6494 - accuracy: 0.6232 - get_f1: 0.6255 - val_loss: 0.7235 - val_accuracy: 0.6144 - val_get_f1: 0.6162
#
# Epoch 00042: val_loss did not improve from 0.53328
# Epoch 43/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6500 - accuracy: 0.6233 - get_f1: 0.6232 - val_loss: 0.6137 - val_accuracy: 0.6144 - val_get_f1: 0.6157
#
# Epoch 00043: val_loss did not improve from 0.53328
# Epoch 44/50
# 1087/1087 [==============================] - 276s 254ms/step - loss: 0.6515 - accuracy: 0.6247 - get_f1: 0.6265 - val_loss: 0.6934 - val_accuracy: 0.6144 - val_get_f1: 0.6177
#
# Epoch 00044: val_loss did not improve from 0.53328
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.999999818536047e-12.
# Epoch 00044: early stopping

# %% [markdown]
# # Statystyki

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12))

# Wykres loss
ax1.plot(history_fn.history['loss'], color='b', label="Training loss")
ax1.plot(history_fn.history['val_loss'], color='r', label="Validation loss")
ax1.set_xticks(numpy.arange(0, len(history_fn.history['val_loss']), 1))
ax1.legend(loc='best', shadow=True)
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')

# Wykres accuracy
ax2.plot(history_fn.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history_fn.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(numpy.arange(0, len(history_fn.history['val_accuracy']), 1))
ax2.legend(loc='best', shadow=True)
ax2.set_ylabel('accuracy')
ax2.set_xlabel('epoch')

# Wykres F1
ax3.plot(history_fn.history['get_f1'], color='b', label="Training f1")
ax3.plot(history_fn.history['val_get_f1'], color='r',label="Validation f1")
ax3.set_xticks(numpy.arange(0, len(history_fn.history['get_f1']), 1))
ax3.legend(loc='best', shadow=True)
ax3.set_ylabel('f1')
ax3.set_xlabel('epoch')


plt.tight_layout()
plt.show()

# %%
stats_df = pd.DataFrame({
    'filename': test['filename'],
    'category': test['category'],
    'predict_fn': None
})

# Mieszamy!
stats_df = stats_df.sample(frac=1).reset_index(drop=True)

stats_df.head()
# Out:
#                                   filename category predict_fn
# 0      ../data/Photos/originals/2wys4z.jpg        1       None
# 1      ../data/Photos/originals/7dm1os.jpg        1       None
# 2  ../data/Photos/photoshops/c4yobf3_0.jpg        0       None
# 3  ../data/Photos/photoshops/c8ohaw8_0.png        0       None
# 4      ../data/Photos/originals/2742s8.jpg        1       None

# %%
validate_generator = data_gen.flow_from_dataframe( 
    dataframe = stats_df,
    x_col = 'filename',
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 4352 validated image filenames.

# %%
predict_fn = model_fn.predict_generator(validate_generator, verbose=True)
# Out:
# 272/272 [==============================] - 54s 199ms/step

# %%
# Zamiana z 0-1 hot encodera na jedno wyjście
stats_df['predict_fn'] = list(map(lambda x: 1 if x > 0.5 else 0,predict_fn))

# %%
stats_df.head()
# Out:
#                                   filename category  predict_fn
# 0      ../data/Photos/originals/2wys4z.jpg        1           1
# 1      ../data/Photos/originals/7dm1os.jpg        1           1
# 2  ../data/Photos/photoshops/c4yobf3_0.jpg        0           1
# 3  ../data/Photos/photoshops/c8ohaw8_0.png        0           0
# 4      ../data/Photos/originals/2742s8.jpg        1           1

# %%
stats_df['predict_fn'].value_counts().plot.bar()

# %%
y_true_fn = stats_df['category'].to_numpy().astype(int)
y_pred_fn = stats_df['predict_fn'].to_numpy().astype(int)

# %%
cm_fn = confusion_matrix(y_true_fn, y_pred_fn)

# %%
plot_cm(cm_fn, ['Originals', 'Photoshops'])

# %%
print(cm_fn)
# Out:
# [[1253  923]
#  [ 759 1417]]

# %%
loss, accuracy, get_f1  = model_fn.evaluate_generator(test_generator, verbose=True)
# Out:
# 272/272 [==============================] - 54s 199ms/step

# %%
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
print(f'Test F1: {get_f1:.3}')
# Out:
# Test loss: 1.04
# Test accuracy: 0.615
# Test F1: 0.614

# %%
accuracy, precision, recall, fscore = countStats(y_true_fn, y_pred_fn)
print(f'Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF-score: {fscore}')
# Out:
# Accuracy: 0.6135110294117647
# Precision: 0.6141594875193285
# Recall: 0.6135110294117647
# F-score: 0.6129614073023181
